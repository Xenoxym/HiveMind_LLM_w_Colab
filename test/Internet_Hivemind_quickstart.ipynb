# %%
# # 安装 flask 和 ngrok
# !pip install flask
# !pip install pyngrok

# from flask import Flask
# from pyngrok import ngrok

# # 创建 Flask 应用
# app = Flask(__name__)

# @app.route('/')
# def home():
#     return "Hello from COLAB 1!"

# ngrok.set_auth_token("2q0WqdIL8HEbZMSU8CXwTFZrR5y_2A9nKPfF8zj8mC2tGkiF1")

# # 启动 ngrok 代理
# public_url = ngrok.connect(5000)
# print('Public URL:', public_url)

# # 启动 Flask 应用
# app.run(port=5000)
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (3.0.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.2.1)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)
# Public URL: NgrokTunnel: "https://488e-34-168-54-187.ngrok-free.app" -> "http://localhost:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [10/Dec/2024 05:43:26] "GET /.ngrok.io HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [10/Dec/2024 05:43:40] "GET /.ngrok.io HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [10/Dec/2024 05:43:42] "GET /.ngrok.io HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [10/Dec/2024 05:44:16] "GET / HTTP/1.1" 200 -
# WARNING:pyngrok.process.ngrok:t=2024-12-10T06:18:10+0000 lvl=warn msg="Stopping forwarder" name=http-5000-37971d5b-7757-4912-9541-c5bff5989302 acceptErr="failed to accept connection: Listener closed"
# WARNING:pyngrok.process.ngrok:t=2024-12-10T06:18:10+0000 lvl=warn msg="Error restarting forwarder" name=http-5000-37971d5b-7757-4912-9541-c5bff5989302 err="failed to start tunnel: session closed"

# %%
# 下载并解压 ngrok
# !wget https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# !tar -xvzf ngrok-v3-stable-linux-amd64.tgz

# 替换 YOUR_NGROK_AUTH_TOKEN 为你的 ngrok 认证令牌
# !./ngrok authtoken 2q0WqdIL8HEbZMSU8CXwTFZrR5y_2A9nKPfF8zj8mC2tGkiF1
# Out:
# --2024-12-10 08:52:18--  https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# Resolving bin.equinox.io (bin.equinox.io)... 99.83.220.108, 35.71.179.82, 75.2.60.68, ...
# Connecting to bin.equinox.io (bin.equinox.io)|99.83.220.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14796857 (14M) [application/octet-stream]
# Saving to: ‘ngrok-v3-stable-linux-amd64.tgz’
#
# ngrok-v3-stable-lin 100%[===================>]  14.11M  6.99MB/s    in 2.0s
#
# 2024-12-10 08:52:21 (6.99 MB/s) - ‘ngrok-v3-stable-linux-amd64.tgz’ saved [14796857/14796857]
#
# ngrok
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !pip install torch==2.2.2
# !pip install torchvision==0.12.0
import torch
import torchvision
print(torch.__version__)
print(torchvision.__version__)
# Out:
# Collecting torch==2.2.2
#   Downloading torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.2)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.2)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.2)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.2)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.2)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.2)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.2)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.2)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.2)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.2)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.2)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch==2.2.2)
#   Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.2) (12.6.85)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.2.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.2.2) (1.3.0)
# Downloading torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 56.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 34.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 30.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 816.8 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.4 MB/s eta 0:00:00
# Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 5.5 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.6.0.74
#     Uninstalling nvidia-cudnn-cu12-9.6.0.74:
#       Successfully uninstalled nvidia-cudnn-cu12-9.6.0.74
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.2.2 which is incompatible.
# torchvision 0.20.1+cu121 requires torch==2.5.1, but you have torch 2.2.2 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvtx-cu12-12.1.105 torch-2.2.2 triton-2.2.0
# Collecting torchvision==0.12.0
#   Downloading torchvision-0.12.0-cp310-cp310-manylinux1_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (2.32.3)
# Collecting torch==1.11.0 (from torchvision==0.12.0)
#   Downloading torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (11.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (2024.8.30)
# Downloading torchvision-0.12.0-cp310-cp310-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 69.0 MB/s eta 0:00:00
# Downloading torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl (750.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 2.6 MB/s eta 0:00:00
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.2
#     Uninstalling torch-2.2.2:
#       Successfully uninstalled torch-2.2.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.13.2 requires torch>=1.13.0, but you have torch 1.11.0 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 1.11.0 which is incompatible.
# Successfully installed torch-1.11.0 torchvision-0.12.0
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /usr/local/lib/python3.10/dist-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warn(f"Failed to load image Python extension: {e}")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3812c5b113cc> in <cell line: 4>()
#       2 get_ipython().system('pip install torchvision==0.12.0')
#       3 import torch
# ----> 4 import torchvision
#       5 print(torch.__version__)
#       6 print(torchvision.__version__)
#
# /usr/local/lib/python3.10/dist-packages/torchvision/__init__.py in <module>
#       5 from torchvision import datasets
#       6 from torchvision import io
# ----> 7 from torchvision import models
#       8 from torchvision import ops
#       9 from torchvision import transforms
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/__init__.py in <module>
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .resnet import *
#       4 from .vgg import *
#       5 from .squeezenet import *
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/convnext.py in <module>
#       7
#       8 from .._internally_replaced_utils import load_state_dict_from_url
# ----> 9 from ..ops.misc import ConvNormActivation
#      10 from ..ops.stochastic_depth import StochasticDepth
#      11 from ..utils import _log_api_usage_once
#
# /usr/local/lib/python3.10/dist-packages/torchvision/ops/__init__.py in <module>
#      23 from .stochastic_depth import stochastic_depth, StochasticDepth
#      24
# ---> 25 _register_custom_op()
#      26
#      27
#
# /usr/local/lib/python3.10/dist-packages/torchvision/ops/_register_onnx_ops.py in _register_custom_op()
#       8
#       9 def _register_custom_op():
# ---> 10     from torch.onnx.symbolic_helper import parse_args
#      11     from torch.onnx.symbolic_opset11 import select, squeeze, unsqueeze
#      12     from torch.onnx.symbolic_opset9 import _cast_Long
#
# /usr/local/lib/python3.10/dist-packages/torch/onnx/__init__.py in <module>
#       4 OperatorExportTypes = _C._onnx.OperatorExportTypes
#       5 TrainingMode = _C._onnx.TrainingMode
# ----> 6 PYTORCH_ONNX_CAFFE2_BUNDLE = _C._onnx.PYTORCH_ONNX_CAFFE2_BUNDLE
#       7
#       8 ONNX_ARCHIVE_MODEL_PROTO_NAME = "__MODEL_PROTO"
#
# AttributeError: module 'torch._C._onnx' has no attribute 'PYTORCH_ONNX_CAFFE2_BUNDLE'

# %%
import torch
import torchvision
print(torch.__version__)
print(torchvision.__version__)
# Out:
# 1.11.0+cu102
# 0.12.0+cu102

# %%
# !pip install hivemind
# Out:
# Collecting hivemind
#   Downloading hivemind-1.1.10.post2.tar.gz (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from hivemind) (6.0.2)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from hivemind) (1.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from hivemind) (1.26.4)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from hivemind) (1.13.1)
# Collecting prefetch_generator>=1.0.1 (from hivemind)
#   Downloading prefetch_generator-1.0.3.tar.gz (4.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from hivemind) (1.1.0)
# Collecting sortedcontainers (from hivemind)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting uvloop>=0.14.0 (from hivemind)
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting grpcio-tools>=1.33.2 (from hivemind)
#   Using cached grpcio_tools-1.68.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from hivemind) (4.25.5)
# Collecting configargparse>=1.2.3 (from hivemind)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl.metadata (23 kB)
# Collecting multiaddr>=0.0.9 (from hivemind)
#   Downloading multiaddr-0.0.9-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting pymultihash>=0.8.2 (from hivemind)
#   Downloading pymultihash-0.8.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: cryptography>=3.4.6 in /usr/local/lib/python3.10/dist-packages (from hivemind) (43.0.3)
# Collecting pydantic<2.0,>=1.8.1 (from hivemind)
#   Downloading pydantic-1.10.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.6/152.6 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from hivemind) (24.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.4.6->hivemind) (1.17.1)
# Collecting protobuf>=3.12.2 (from hivemind)
#   Using cached protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: grpcio>=1.68.1 in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.33.2->hivemind) (1.68.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.33.2->hivemind) (75.1.0)
# Collecting varint (from multiaddr>=0.0.9->hivemind)
#   Downloading varint-1.0.2.tar.gz (1.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from multiaddr>=0.0.9->hivemind) (1.16.0)
# Collecting base58 (from multiaddr>=0.0.9->hivemind)
#   Downloading base58-2.1.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting netaddr (from multiaddr>=0.0.9->hivemind)
#   Downloading netaddr-1.3.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.0,>=1.8.1->hivemind) (4.12.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.4.6->hivemind) (2.22)
# Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Using cached grpcio_tools-1.68.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
# Downloading multiaddr-0.0.9-py2.py3-none-any.whl (16 kB)
# Using cached protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading pydantic-1.10.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 47.2 MB/s eta 0:00:00
# Downloading pymultihash-0.8.2-py3-none-any.whl (13 kB)
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 76.4 MB/s eta 0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Downloading netaddr-1.3.0-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 72.4 MB/s eta 0:00:00
# Building wheels for collected packages: hivemind, prefetch_generator, varint
#   Building wheel for hivemind (pyproject.toml) ... done
#   Created wheel for hivemind: filename=hivemind-1.1.10.post2-py3-none-any.whl size=9012235 sha256=07103fdaad920398aef62d9032239e081d5c94a0a5a3d4c6e84ad521213e7fee
#   Stored in directory: /root/.cache/pip/wheels/53/98/e3/d51ae54ae8302c5a1872fae2e85a8e8291651af19f550965c1
#   Building wheel for prefetch_generator (setup.py) ... done
#   Created wheel for prefetch_generator: filename=prefetch_generator-1.0.3-py3-none-any.whl size=4758 sha256=991948d67bcbb7ff2947f5b1f1cad9e62f1b91bb9aa60a9072c7a6ea7026f8f3
#   Stored in directory: /root/.cache/pip/wheels/65/65/44/ed059bc23eeda93cfb19b58113423882cd9febae7ebf3f9ddf
#   Building wheel for varint (setup.py) ... done
#   Created wheel for varint: filename=varint-1.0.2-py3-none-any.whl size=1962 sha256=3ed8c5891310116b51e271686d0a208af9cd769495c2b9d016cfdeeae25af8d2
#   Stored in directory: /root/.cache/pip/wheels/39/48/5e/33919c52a2a695a512ca394a5308dd12626a40bbcd288de814
# Successfully built hivemind prefetch_generator varint
# Installing collected packages: varint, sortedcontainers, pymultihash, prefetch_generator, uvloop, pydantic, protobuf, netaddr, configargparse, base58, multiaddr, grpcio-tools, hivemind
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.3
#     Uninstalling pydantic-2.10.3:
#       Successfully uninstalled pydantic-2.10.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.20 requires pydantic>=2.7.0, but you have pydantic 1.10.19 which is incompatible.
# langchain 0.3.9 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.19 which is incompatible.
# langchain-core 0.3.21 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 1.10.19 which is incompatible.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.
# Successfully installed base58-2.1.1 configargparse-1.7 grpcio-tools-1.68.1 hivemind-1.1.10.post2 multiaddr-0.0.9 netaddr-1.3.0 prefetch_generator-1.0.3 protobuf-5.29.1 pydantic-1.10.19 pymultihash-0.8.2 sortedcontainers-2.4.0 uvloop-0.21.0 varint-1.0.2

# %%
import hivemind
dht = hivemind.DHT(
    host_maddrs=["/ip4/0.0.0.0/tcp/0", "/ip4/0.0.0.0/udp/0/quic"],
    start=True)

print('\n'.join(str(addr) for addr in dht.get_visible_maddrs()))
print("Global IP:", hivemind.utils.networking.choose_ip_address(dht.get_visible_maddrs()))
# Out:
# /ip4/172.28.0.12/tcp/33539/p2p/12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW
# /ip4/127.0.0.1/tcp/33539/p2p/12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW
# /ip4/172.28.0.12/udp/42771/quic/p2p/12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW
# /ip4/127.0.0.1/udp/42771/quic/p2p/12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW
# Global IP: 172.28.0.12

# %%
print('\n'.join(str(addr) for addr in dht.get_visible_maddrs()))
print("Global IP:", hivemind.utils.networking.choose_ip_address(dht.get_visible_maddrs()))

# %%
# 暴露端口 33637（假设该端口用于通信）
# !nohup ./ngrok tcp 33539 > ngrok.log 2>&1 &

# %%
# !curl -s http://127.0.0.1:4040/api/tunnels | grep -Eo '"public_url":"tcp://[^"]+"' | cut -d':' -f2- | tr -d '"'
# Out:
# tcp://0.tcp.jp.ngrok.io:15048

# %%
import socket

# 输入你的 ngrok 公网地址
ngrok_host = "0.tcp.jp.ngrok.io"

# 获取 IP 地址
ip_address = socket.gethostbyname(ngrok_host)

# 输出 IP 地址
print(f"IP Address of {ngrok_host}: {ip_address}")
# Out:
# IP Address of 0.tcp.jp.ngrok.io: 35.76.159.227

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from tqdm.auto import tqdm

import hivemind

# Create dataset and model, same as in the basic tutorial
# For this basic tutorial, we download only the training set
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)

model = nn.Sequential(nn.Conv2d(3, 16, (5, 5)), nn.MaxPool2d(2, 2), nn.ReLU(),
                      nn.Conv2d(16, 32, (5, 5)), nn.MaxPool2d(2, 2), nn.ReLU(),
                      nn.Flatten(), nn.Linear(32 * 5 * 5, 10))
opt = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Create DHT: a decentralized key-value storage shared between peers
# dht = hivemind.DHT(start=True)

# dht = hivemind.DHT(
#     host_maddrs=["/ip4/0.0.0.0/tcp/0", "/ip4/0.0.0.0/udp/0/quic"],
#     initial_peers=[
#         "/ip4/3.140.223.7/tcp/16497/p2p/12D3KooWBCdJnh6r7n4L4zxCd3iEofpNDbJKLXQ5gq1DqK6RYbcH",
#     ], start=True)

# dht = hivemind.DHT(
#     host_maddrs=["/ip4/0.0.0.0/tcp/0", "/ip4/0.0.0.0/udp/0/quic"],
#     initial_peers=[
#         f"/ip4/{ip_address}/tcp/16497/p2p/12D3KooWBCdJnh6r7n4L4zxCd3iEofpNDbJKLXQ5gq1DqK6RYbcH",
#     ], start=True,client_mode=True)



print("To join the training, use initial_peers =", [str(addr) for addr in dht.get_visible_maddrs()])

# Set up a decentralized optimizer that will average with peers in background
opt = hivemind.Optimizer(
    dht=dht,                  # use a DHT that is connected with other peers
    run_id='my_cifar_run',    # unique identifier of this collaborative run
    batch_size_per_step=32,   # each call to opt.step adds this many samples towards the next epoch
    target_batch_size=10000,  # after peers collectively process this many samples, average weights and begin the next epoch
    optimizer=opt,            # wrap the SGD optimizer defined above
    use_local_updates=True,   # perform optimizer steps with local gradients, average parameters in background
    matchmaking_time=3.0,     # when averaging parameters, gather peers in background for up to this many seconds
    averaging_timeout=10.0,   # give up on averaging if not successful in this many seconds
    verbose=True              # print logs incessently
)

# Note: if you intend to use GPU, switch to it only after the decentralized optimizer is created
with tqdm() as progressbar:
    while True:
        for x_batch, y_batch in torch.utils.data.DataLoader(trainset, shuffle=True, batch_size=32):
            opt.zero_grad()
            loss = F.cross_entropy(model(x_batch), y_batch)
            loss.backward()
            opt.step()

            progressbar.desc = f"loss = {loss.item():.3f}"
            progressbar.update()

# num_epochs = 2  # 设置你想要的 epoch 数
# for epoch in range(num_epochs):
#     with tqdm(total=len(trainset), desc=f"Epoch {epoch+1}/{num_epochs}") as progressbar:
#         for x_batch, y_batch in torch.utils.data.DataLoader(trainset, shuffle=True, batch_size=32):
#             opt.zero_grad()
#             loss = F.cross_entropy(model(x_batch), y_batch)
#             loss.backward()
#             opt.step()

#             progressbar.set_postfix(loss=loss.item())
#             progressbar.update(len(x_batch))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Dec 10 09:04:56.311 [INFO] Found no active peers: None
# Dec 10 09:04:56.321 [INFO] Initializing optimizer manually since it has no tensors in state dict. To override this, provide initialize_optimizer=False
# To join the training, use initial_peers = ['/ip4/172.28.0.12/tcp/33539/p2p/12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW', '/ip4/127.0.0.1/tcp/33539/p2p/12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW', '/ip4/172.28.0.12/udp/42771/quic/p2p/12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW', '/ip4/127.0.0.1/udp/42771/quic/p2p/12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW']
# Dec 10 09:04:56.391 [WARN] [hivemind.averaging.matchmaking.__init__:54] It is recommended to use request_timeout smaller than min_matchmaking_time. Otherwise, matchmaking can cause deadlocks in some rare cases. Please see Matchmaking docstring.
# 0it [00:00, ?it/s]
# Dec 10 09:04:59.331 [INFO] my_cifar_run accumulated 2016 samples for epoch #0 from 1 peers. ETA 10.98 sec (refresh in 2.75 sec)
# Dec 10 09:05:02.081 [INFO] my_cifar_run accumulated 4224 samples for epoch #0 from 1 peers. ETA 5.42 sec (refresh in 1.35 sec)
# Dec 10 09:05:03.441 [INFO] my_cifar_run accumulated 5664 samples for epoch #0 from 1 peers. ETA 3.95 sec (refresh in 0.99 sec)
# Dec 10 09:05:04.435 [INFO] my_cifar_run accumulated 6720 samples for epoch #0 from 1 peers. ETA 2.98 sec (refresh in 0.74 sec)
# Dec 10 09:05:05.193 [INFO] my_cifar_run accumulated 7520 samples for epoch #0 from 1 peers. ETA 2.26 sec (refresh in 0.57 sec)
# Dec 10 09:05:05.767 [INFO] my_cifar_run accumulated 8064 samples for epoch #0 from 1 peers. ETA 1.85 sec (refresh in 0.50 sec)
# Dec 10 09:05:06.273 [INFO] my_cifar_run accumulated 8608 samples for epoch #0 from 1 peers. ETA 1.32 sec (refresh in 0.50 sec)
# Dec 10 09:05:06.784 [INFO] my_cifar_run accumulated 9120 samples for epoch #0 from 1 peers. ETA 0.85 sec (refresh in 0.50 sec)
# Dec 10 09:05:07.294 [INFO] my_cifar_run accumulated 9664 samples for epoch #0 from 1 peers. ETA 0.31 sec (refresh in 0.50 sec)
# Dec 10 09:05:07.639 [INFO] Transitioning to epoch 1
# Dec 10 09:05:07.799 [INFO] my_cifar_run accumulated 160 samples for epoch #1 from 1 peers. ETA 9.31 sec (refresh in 2.33 sec)
# Dec 10 09:05:10.142 [INFO] my_cifar_run accumulated 2624 samples for epoch #1 from 1 peers. ETA 6.90 sec (refresh in 1.72 sec)
# Dec 10 09:05:11.870 [INFO] my_cifar_run accumulated 4224 samples for epoch #1 from 1 peers. ETA 7.48 sec (refresh in 1.87 sec)
# Dec 10 09:05:13.746 [INFO] my_cifar_run accumulated 5664 samples for epoch #1 from 1 peers. ETA 5.78 sec (refresh in 1.44 sec)
# Dec 10 09:05:15.195 [INFO] my_cifar_run accumulated 6688 samples for epoch #1 from 1 peers. ETA 4.66 sec (refresh in 1.17 sec)
# Dec 10 09:05:16.367 [INFO] my_cifar_run accumulated 7712 samples for epoch #1 from 1 peers. ETA 2.27 sec (refresh in 0.57 sec)
# Dec 10 09:05:16.941 [INFO] my_cifar_run accumulated 8288 samples for epoch #1 from 1 peers. ETA 1.61 sec (refresh in 0.50 sec)
# Dec 10 09:05:17.450 [INFO] my_cifar_run accumulated 8832 samples for epoch #1 from 1 peers. ETA 1.05 sec (refresh in 0.50 sec)
# Dec 10 09:05:17.957 [INFO] my_cifar_run accumulated 9376 samples for epoch #1 from 1 peers. ETA 0.57 sec (refresh in 0.50 sec)
# Dec 10 09:05:18.470 [INFO] my_cifar_run accumulated 9888 samples for epoch #1 from 1 peers. ETA 0.08 sec (refresh in 0.50 sec)
# Dec 10 09:05:18.568 [INFO] Transitioning to epoch 2
# Dec 10 09:05:18.975 [INFO] my_cifar_run accumulated 416 samples for epoch #2 from 1 peers. ETA 8.85 sec (refresh in 2.21 sec)
# Dec 10 09:05:21.196 [INFO] my_cifar_run accumulated 2752 samples for epoch #2 from 1 peers. ETA 6.89 sec (refresh in 1.72 sec)
# Dec 10 09:05:22.927 [INFO] my_cifar_run accumulated 4544 samples for epoch #2 from 1 peers. ETA 5.03 sec (refresh in 1.26 sec)
# Dec 10 09:05:24.195 [INFO] my_cifar_run accumulated 5888 samples for epoch #2 from 1 peers. ETA 3.80 sec (refresh in 0.95 sec)
# Dec 10 09:05:25.160 [INFO] my_cifar_run accumulated 6912 samples for epoch #2 from 1 peers. ETA 2.82 sec (refresh in 0.71 sec)
# Dec 10 09:05:25.891 [INFO] my_cifar_run accumulated 7648 samples for epoch #2 from 1 peers. ETA 2.32 sec (refresh in 0.58 sec)
# Dec 10 09:05:26.477 [INFO] my_cifar_run accumulated 8064 samples for epoch #2 from 1 peers. ETA 2.48 sec (refresh in 0.62 sec)
# Dec 10 09:05:27.105 [INFO] my_cifar_run accumulated 8544 samples for epoch #2 from 1 peers. ETA 1.91 sec (refresh in 0.50 sec)
# Dec 10 09:05:27.609 [INFO] my_cifar_run accumulated 8896 samples for epoch #2 from 1 peers. ETA 1.47 sec (refresh in 0.50 sec)
# Dec 10 09:05:28.121 [INFO] my_cifar_run accumulated 9280 samples for epoch #2 from 1 peers. ETA 0.92 sec (refresh in 0.50 sec)
# Dec 10 09:05:28.625 [INFO] my_cifar_run accumulated 9632 samples for epoch #2 from 1 peers. ETA 0.48 sec (refresh in 0.50 sec)
# Dec 10 09:05:29.112 [INFO] Transitioning to epoch 3
# Dec 10 09:05:29.140 [INFO] my_cifar_run accumulated 0 samples for epoch #3 from 1 peers. ETA 13.57 sec (refresh in 3.39 sec)
# Dec 10 09:05:32.538 [INFO] my_cifar_run accumulated 3040 samples for epoch #3 from 1 peers. ETA 6.66 sec (refresh in 1.66 sec)
# Dec 10 09:05:34.210 [INFO] my_cifar_run accumulated 4800 samples for epoch #3 from 1 peers. ETA 4.88 sec (refresh in 1.22 sec)
# Dec 10 09:05:35.434 [INFO] my_cifar_run accumulated 6080 samples for epoch #3 from 1 peers. ETA 3.62 sec (refresh in 0.91 sec)
# Dec 10 09:05:36.346 [INFO] my_cifar_run accumulated 7008 samples for epoch #3 from 1 peers. ETA 2.85 sec (refresh in 0.71 sec)
# Dec 10 09:05:37.064 [INFO] my_cifar_run accumulated 7744 samples for epoch #3 from 1 peers. ETA 2.18 sec (refresh in 0.54 sec)
# Dec 10 09:05:37.612 [INFO] my_cifar_run accumulated 8320 samples for epoch #3 from 1 peers. ETA 1.65 sec (refresh in 0.50 sec)
# Dec 10 09:05:38.117 [INFO] my_cifar_run accumulated 8864 samples for epoch #3 from 1 peers. ETA 1.03 sec (refresh in 0.50 sec)
# Dec 10 09:05:38.625 [INFO] my_cifar_run accumulated 9376 samples for epoch #3 from 1 peers. ETA 0.60 sec (refresh in 0.50 sec)
# Dec 10 09:05:39.139 [INFO] my_cifar_run accumulated 9920 samples for epoch #3 from 1 peers. ETA 0.05 sec (refresh in 0.50 sec)
# Dec 10 09:05:39.209 [INFO] Transitioning to epoch 4
# Dec 10 09:05:39.645 [INFO] my_cifar_run accumulated 416 samples for epoch #4 from 1 peers. ETA 9.79 sec (refresh in 2.45 sec)
# Dec 10 09:05:42.105 [INFO] my_cifar_run accumulated 2624 samples for epoch #4 from 1 peers. ETA 9.86 sec (refresh in 2.47 sec)
# Dec 10 09:05:44.583 [INFO] my_cifar_run accumulated 4384 samples for epoch #4 from 1 peers. ETA 8.23 sec (refresh in 2.06 sec)
# Dec 10 09:05:46.647 [INFO] my_cifar_run accumulated 6304 samples for epoch #4 from 1 peers. ETA 3.58 sec (refresh in 0.90 sec)
# Dec 10 09:05:47.548 [INFO] my_cifar_run accumulated 7232 samples for epoch #4 from 1 peers. ETA 2.65 sec (refresh in 0.66 sec)
# Dec 10 09:05:48.215 [INFO] my_cifar_run accumulated 7968 samples for epoch #4 from 1 peers. ETA 1.86 sec (refresh in 0.50 sec)
# Dec 10 09:05:48.721 [INFO] my_cifar_run accumulated 8480 samples for epoch #4 from 1 peers. ETA 1.45 sec (refresh in 0.50 sec)
# Dec 10 09:05:49.225 [INFO] my_cifar_run accumulated 9024 samples for epoch #4 from 1 peers. ETA 0.87 sec (refresh in 0.50 sec)
# Dec 10 09:05:49.732 [INFO] my_cifar_run accumulated 9536 samples for epoch #4 from 1 peers. ETA 0.43 sec (refresh in 0.50 sec)
# Dec 10 09:05:50.155 [INFO] Transitioning to epoch 5
# Dec 10 09:05:50.237 [INFO] my_cifar_run accumulated 64 samples for epoch #5 from 1 peers. ETA 9.06 sec (refresh in 2.27 sec)
# Dec 10 09:05:52.510 [INFO] my_cifar_run accumulated 2432 samples for epoch #5 from 1 peers. ETA 7.60 sec (refresh in 1.90 sec)
# Dec 10 09:05:54.414 [INFO] my_cifar_run accumulated 4448 samples for epoch #5 from 1 peers. ETA 5.07 sec (refresh in 1.27 sec)
# Dec 10 09:05:55.693 [INFO] my_cifar_run accumulated 5664 samples for epoch #5 from 1 peers. ETA 5.10 sec (refresh in 1.27 sec)
# Dec 10 09:05:56.982 [INFO] my_cifar_run accumulated 6624 samples for epoch #5 from 1 peers. ETA 4.28 sec (refresh in 1.07 sec)
# Dec 10 09:05:58.062 [INFO] my_cifar_run accumulated 7424 samples for epoch #5 from 1 peers. ETA 3.37 sec (refresh in 0.84 sec)
# Dec 10 09:05:58.919 [INFO] my_cifar_run accumulated 8032 samples for epoch #5 from 1 peers. ETA 2.81 sec (refresh in 0.70 sec)
# Dec 10 09:05:59.637 [INFO] my_cifar_run accumulated 8512 samples for epoch #5 from 1 peers. ETA 2.18 sec (refresh in 0.54 sec)
# Dec 10 09:06:00.187 [INFO] my_cifar_run accumulated 8992 samples for epoch #5 from 1 peers. ETA 1.13 sec (refresh in 0.50 sec)
# Dec 10 09:06:00.694 [INFO] my_cifar_run accumulated 9504 samples for epoch #5 from 1 peers. ETA 0.51 sec (refresh in 0.50 sec)
# Dec 10 09:06:01.165 [INFO] Transitioning to epoch 6
# Dec 10 09:06:01.199 [INFO] my_cifar_run accumulated 0 samples for epoch #6 from 1 peers. ETA 9.46 sec (refresh in 2.37 sec)
# Dec 10 09:06:03.595 [INFO] my_cifar_run accumulated 2496 samples for epoch #6 from 1 peers. ETA 7.14 sec (refresh in 1.79 sec)
# Dec 10 09:06:05.390 [INFO] my_cifar_run accumulated 4448 samples for epoch #6 from 1 peers. ETA 5.11 sec (refresh in 1.28 sec)
# Dec 10 09:06:06.685 [INFO] my_cifar_run accumulated 5728 samples for epoch #6 from 1 peers. ETA 4.30 sec (refresh in 1.08 sec)
# Dec 10 09:06:07.771 [INFO] my_cifar_run accumulated 6880 samples for epoch #6 from 1 peers. ETA 2.90 sec (refresh in 0.72 sec)
# Dec 10 09:06:08.500 [INFO] my_cifar_run accumulated 7648 samples for epoch #6 from 1 peers. ETA 2.19 sec (refresh in 0.55 sec)
# Dec 10 09:06:09.056 [INFO] my_cifar_run accumulated 8256 samples for epoch #6 from 1 peers. ETA 1.57 sec (refresh in 0.50 sec)
# Dec 10 09:06:09.560 [INFO] my_cifar_run accumulated 8736 samples for epoch #6 from 1 peers. ETA 1.23 sec (refresh in 0.50 sec)
# Dec 10 09:06:10.068 [INFO] my_cifar_run accumulated 9248 samples for epoch #6 from 1 peers. ETA 0.71 sec (refresh in 0.50 sec)
# Dec 10 09:06:10.574 [INFO] my_cifar_run accumulated 9600 samples for epoch #6 from 1 peers. ETA 0.49 sec (refresh in 0.50 sec)
# Dec 10 09:06:11.080 [INFO] my_cifar_run accumulated 9984 samples for epoch #6 from 1 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:06:11.105 [INFO] Transitioning to epoch 7
# Dec 10 09:06:11.585 [INFO] my_cifar_run accumulated 320 samples for epoch #7 from 1 peers. ETA 13.24 sec (refresh in 3.31 sec)
# Dec 10 09:06:15.106 [INFO] my_cifar_run accumulated 2880 samples for epoch #7 from 1 peers. ETA 7.32 sec (refresh in 1.83 sec)
# Dec 10 09:06:17.147 [INFO] my_cifar_run accumulated 5312 samples for epoch #7 from 2 peers. ETA 2.51 sec (refresh in 1.00 sec)
# Dec 10 09:06:18.360 [INFO] my_cifar_run accumulated 7168 samples for epoch #7 from 2 peers. ETA 1.50 sec (refresh in 0.60 sec)
# Dec 10 09:06:19.160 [INFO] my_cifar_run accumulated 8512 samples for epoch #7 from 2 peers. ETA 0.59 sec (refresh in 0.50 sec)
# Dec 10 09:06:19.872 [INFO] my_cifar_run accumulated 9536 samples for epoch #7 from 2 peers. ETA 0.01 sec (refresh in 0.50 sec)
# Dec 10 09:06:19.874 [INFO] Transitioning to epoch 8
# Dec 10 09:06:19.919 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:06:20.566 [INFO] my_cifar_run accumulated 64 samples for epoch #8 from 2 peers. ETA 6.04 sec (refresh in 2.42 sec)
# Dec 10 09:06:23.176 [INFO] my_cifar_run accumulated 64 samples for epoch #8 from 2 peers. ETA 3.43 sec (refresh in 1.37 sec)
# Dec 10 09:06:23.567 [INFO] Averaged parameters with 2 peers
# Dec 10 09:06:23.576 [INFO] Received parameters from background averaging round
# Dec 10 09:06:24.768 [INFO] my_cifar_run accumulated 1504 samples for epoch #8 from 2 peers. ETA 9.99 sec (refresh in 4.00 sec)
# Dec 10 09:06:29.001 [INFO] my_cifar_run accumulated 6144 samples for epoch #8 from 2 peers. ETA 3.21 sec (refresh in 1.28 sec)
# Dec 10 09:06:30.485 [INFO] my_cifar_run accumulated 8096 samples for epoch #8 from 2 peers. ETA 1.04 sec (refresh in 0.50 sec)
# Dec 10 09:06:31.183 [INFO] my_cifar_run accumulated 9024 samples for epoch #8 from 2 peers. ETA 0.46 sec (refresh in 0.50 sec)
# Dec 10 09:06:31.641 [INFO] Transitioning to epoch 9
# Dec 10 09:06:31.744 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:06:31.929 [INFO] my_cifar_run accumulated 0 samples for epoch #9 from 2 peers. ETA 6.38 sec (refresh in 2.55 sec)
# Dec 10 09:06:34.679 [INFO] my_cifar_run accumulated 64 samples for epoch #9 from 2 peers. ETA 4.17 sec (refresh in 1.67 sec)
# Dec 10 09:06:35.254 [INFO] Averaged parameters with 2 peers
# Dec 10 09:06:35.259 [INFO] Received parameters from background averaging round
# Dec 10 09:06:36.557 [INFO] my_cifar_run accumulated 1856 samples for epoch #9 from 2 peers. ETA 7.32 sec (refresh in 2.93 sec)
# Dec 10 09:06:39.703 [INFO] my_cifar_run accumulated 6752 samples for epoch #9 from 2 peers. ETA 1.76 sec (refresh in 0.71 sec)
# Dec 10 09:06:40.602 [INFO] my_cifar_run accumulated 7840 samples for epoch #9 from 2 peers. ETA 1.58 sec (refresh in 0.63 sec)
# Dec 10 09:06:41.453 [INFO] my_cifar_run accumulated 8768 samples for epoch #9 from 2 peers. ETA 0.88 sec (refresh in 0.50 sec)
# Dec 10 09:06:42.149 [INFO] my_cifar_run accumulated 9600 samples for epoch #9 from 2 peers. ETA 0.08 sec (refresh in 0.50 sec)
# Dec 10 09:06:42.255 [INFO] Transitioning to epoch 10
# Dec 10 09:06:42.307 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:06:42.844 [INFO] my_cifar_run accumulated 64 samples for epoch #10 from 2 peers. ETA 8.77 sec (refresh in 3.51 sec)
# Dec 10 09:06:45.835 [INFO] Averaged parameters with 2 peers
# Dec 10 09:06:45.838 [INFO] Received parameters from background averaging round
# Dec 10 09:06:46.553 [INFO] my_cifar_run accumulated 800 samples for epoch #10 from 2 peers. ETA 21.34 sec (refresh in 8.54 sec)
# Dec 10 09:06:55.305 [INFO] my_cifar_run accumulated 13696 samples for epoch #10 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:06:55.357 [INFO] Transitioning to epoch 11
# Dec 10 09:06:55.429 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:06:55.999 [INFO] my_cifar_run accumulated 32 samples for epoch #11 from 2 peers. ETA 8.54 sec (refresh in 3.42 sec)
# Dec 10 09:06:58.981 [INFO] Averaged parameters with 2 peers
# Dec 10 09:06:58.987 [INFO] Received parameters from background averaging round
# Dec 10 09:06:59.625 [INFO] my_cifar_run accumulated 640 samples for epoch #11 from 2 peers. ETA 23.71 sec (refresh in 9.48 sec)
# Dec 10 09:07:09.322 [INFO] my_cifar_run accumulated 32 samples for epoch #12 from 2 peers. ETA 5.15 sec (refresh in 2.06 sec)
# Dec 10 09:07:09.360 [INFO] Transitioning to epoch 12
# Dec 10 09:07:09.433 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:07:11.574 [INFO] my_cifar_run accumulated 64 samples for epoch #12 from 2 peers. ETA 3.06 sec (refresh in 1.22 sec)
# Dec 10 09:07:12.024 [INFO] Averaged parameters with 2 peers
# Dec 10 09:07:12.027 [INFO] Received parameters from background averaging round
# Dec 10 09:07:13.003 [INFO] my_cifar_run accumulated 1344 samples for epoch #12 from 2 peers. ETA 11.68 sec (refresh in 4.67 sec)
# Dec 10 09:07:17.872 [INFO] my_cifar_run accumulated 9152 samples for epoch #12 from 2 peers. ETA 0.31 sec (refresh in 0.50 sec)
# Dec 10 09:07:18.199 [INFO] Transitioning to epoch 13
# Dec 10 09:07:18.243 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:07:18.564 [INFO] my_cifar_run accumulated 32 samples for epoch #13 from 2 peers. ETA 5.86 sec (refresh in 2.35 sec)
# Dec 10 09:07:21.110 [INFO] my_cifar_run accumulated 32 samples for epoch #13 from 2 peers. ETA 4.75 sec (refresh in 1.90 sec)
# Dec 10 09:07:23.203 [INFO] my_cifar_run accumulated 32 samples for epoch #13 from 2 peers. ETA 3.54 sec (refresh in 1.42 sec)
# Dec 10 09:07:24.792 [INFO] Averaged parameters with 2 peers
# Dec 10 09:07:24.795 [INFO] Received parameters from background averaging round
# Dec 10 09:07:24.817 [INFO] my_cifar_run accumulated 64 samples for epoch #13 from 2 peers. ETA 1.99 sec (refresh in 0.80 sec)
# Dec 10 09:07:25.817 [INFO] my_cifar_run accumulated 1216 samples for epoch #13 from 2 peers. ETA 13.52 sec (refresh in 5.41 sec)
# Dec 10 09:07:31.427 [INFO] my_cifar_run accumulated 10080 samples for epoch #13 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:07:31.440 [INFO] Transitioning to epoch 14
# Dec 10 09:07:31.500 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:07:32.129 [INFO] my_cifar_run accumulated 32 samples for epoch #14 from 2 peers. ETA 5.68 sec (refresh in 2.27 sec)
# Dec 10 09:07:34.716 [INFO] my_cifar_run accumulated 64 samples for epoch #14 from 2 peers. ETA 3.63 sec (refresh in 1.45 sec)
# Dec 10 09:07:35.141 [INFO] Averaged parameters with 2 peers
# Dec 10 09:07:35.143 [INFO] Received parameters from background averaging round
# Dec 10 09:07:36.371 [INFO] my_cifar_run accumulated 1088 samples for epoch #14 from 2 peers. ETA 16.24 sec (refresh in 6.50 sec)
# Dec 10 09:07:43.065 [INFO] my_cifar_run accumulated 32 samples for epoch #15 from 2 peers. ETA 6.34 sec (refresh in 2.54 sec)
# Dec 10 09:07:43.096 [INFO] Transitioning to epoch 15
# Dec 10 09:07:43.146 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:07:45.793 [INFO] my_cifar_run accumulated 64 samples for epoch #15 from 2 peers. ETA 3.50 sec (refresh in 1.40 sec)
# Dec 10 09:07:46.097 [INFO] Averaged parameters with 2 peers
# Dec 10 09:07:46.100 [INFO] Received parameters from background averaging round
# Dec 10 09:07:47.410 [INFO] my_cifar_run accumulated 1888 samples for epoch #15 from 2 peers. ETA 6.87 sec (refresh in 2.75 sec)
# Dec 10 09:07:50.356 [INFO] my_cifar_run accumulated 5760 samples for epoch #15 from 2 peers. ETA 3.31 sec (refresh in 1.33 sec)
# Dec 10 09:07:51.907 [INFO] my_cifar_run accumulated 7488 samples for epoch #15 from 2 peers. ETA 1.92 sec (refresh in 0.77 sec)
# Dec 10 09:07:52.878 [INFO] my_cifar_run accumulated 8576 samples for epoch #15 from 2 peers. ETA 1.00 sec (refresh in 0.50 sec)
# Dec 10 09:07:53.593 [INFO] my_cifar_run accumulated 9504 samples for epoch #15 from 2 peers. ETA 0.09 sec (refresh in 0.50 sec)
# Dec 10 09:07:53.703 [INFO] Transitioning to epoch 16
# Dec 10 09:07:53.753 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:07:54.289 [INFO] my_cifar_run accumulated 64 samples for epoch #16 from 2 peers. ETA 6.78 sec (refresh in 2.71 sec)
# Dec 10 09:07:57.197 [INFO] my_cifar_run accumulated 64 samples for epoch #16 from 2 peers. ETA 3.87 sec (refresh in 1.55 sec)
# Dec 10 09:07:57.392 [INFO] Averaged parameters with 2 peers
# Dec 10 09:07:57.395 [INFO] Received parameters from background averaging round
# Dec 10 09:07:58.963 [INFO] my_cifar_run accumulated 2208 samples for epoch #16 from 2 peers. ETA 6.06 sec (refresh in 2.42 sec)
# Dec 10 09:08:01.591 [INFO] my_cifar_run accumulated 6464 samples for epoch #16 from 2 peers. ETA 1.96 sec (refresh in 0.79 sec)
# Dec 10 09:08:02.825 [INFO] my_cifar_run accumulated 8256 samples for epoch #16 from 2 peers. ETA 0.69 sec (refresh in 0.50 sec)
# Dec 10 09:08:03.544 [INFO] my_cifar_run accumulated 9472 samples for epoch #16 from 2 peers. ETA 0.11 sec (refresh in 0.50 sec)
# Dec 10 09:08:03.703 [INFO] Transitioning to epoch 17
# Dec 10 09:08:03.752 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:08:04.238 [INFO] my_cifar_run accumulated 64 samples for epoch #17 from 2 peers. ETA 6.61 sec (refresh in 2.64 sec)
# Dec 10 09:08:07.074 [INFO] my_cifar_run accumulated 64 samples for epoch #17 from 2 peers. ETA 3.77 sec (refresh in 1.51 sec)
# Dec 10 09:08:07.338 [INFO] Averaged parameters with 2 peers
# Dec 10 09:08:07.341 [INFO] Received parameters from background averaging round
# Dec 10 09:08:08.808 [INFO] my_cifar_run accumulated 2048 samples for epoch #17 from 2 peers. ETA 6.66 sec (refresh in 2.66 sec)
# Dec 10 09:08:11.683 [INFO] my_cifar_run accumulated 5632 samples for epoch #17 from 2 peers. ETA 1.51 sec (refresh in 0.60 sec)
# Dec 10 09:08:12.498 [INFO] my_cifar_run accumulated 6432 samples for epoch #17 from 2 peers. ETA 0.73 sec (refresh in 0.50 sec)
# Dec 10 09:08:13.197 [INFO] my_cifar_run accumulated 7072 samples for epoch #17 from 2 peers. ETA 0.05 sec (refresh in 0.50 sec)
# Dec 10 09:08:13.254 [INFO] Transitioning to epoch 18
# Dec 10 09:08:13.296 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:08:13.889 [INFO] my_cifar_run accumulated 32 samples for epoch #18 from 2 peers. ETA 5.68 sec (refresh in 2.27 sec)
# Dec 10 09:08:16.355 [INFO] my_cifar_run accumulated 32 samples for epoch #18 from 2 peers. ETA 4.29 sec (refresh in 1.72 sec)
# Dec 10 09:08:18.302 [INFO] my_cifar_run accumulated 32 samples for epoch #18 from 2 peers. ETA 3.20 sec (refresh in 1.28 sec)
# Dec 10 09:08:19.775 [INFO] my_cifar_run accumulated 32 samples for epoch #18 from 2 peers. ETA 2.37 sec (refresh in 0.95 sec)
# Dec 10 09:08:20.917 [INFO] my_cifar_run accumulated 32 samples for epoch #18 from 2 peers. ETA 1.73 sec (refresh in 0.69 sec)
# Dec 10 09:08:21.803 [INFO] my_cifar_run accumulated 32 samples for epoch #18 from 2 peers. ETA 1.23 sec (refresh in 0.50 sec)
# Dec 10 09:08:22.496 [INFO] my_cifar_run accumulated 32 samples for epoch #18 from 2 peers. ETA 0.84 sec (refresh in 0.50 sec)
# Dec 10 09:08:23.191 [INFO] my_cifar_run accumulated 32 samples for epoch #18 from 2 peers. ETA 0.45 sec (refresh in 0.50 sec)
# Dec 10 09:08:23.265 [INFO] Averaging failed with <class 'concurrent.futures._base.TimeoutError'>
# Dec 10 09:08:23.268 [INFO] Received parameters from background averaging round
# Dec 10 09:08:23.637 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:08:23.680 [INFO] Transitioning to epoch 19
# Dec 10 09:08:23.731 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:08:23.905 [INFO] my_cifar_run accumulated 0 samples for epoch #19 from 2 peers. ETA 12.04 sec (refresh in 4.82 sec)
# Dec 10 09:08:28.919 [INFO] my_cifar_run accumulated 32 samples for epoch #19 from 2 peers. ETA 11.20 sec (refresh in 4.48 sec)
# Dec 10 09:08:33.598 [INFO] my_cifar_run accumulated 32 samples for epoch #19 from 2 peers. ETA 10.58 sec (refresh in 4.23 sec)
# Dec 10 09:08:33.694 [INFO] Averaging failed with <class 'concurrent.futures._base.TimeoutError'>
# Dec 10 09:08:33.698 [INFO] Received parameters from background averaging round
# Dec 10 09:08:34.069 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:08:38.024 [INFO] my_cifar_run accumulated 3968 samples for epoch #19 from 2 peers. ETA 3.59 sec (refresh in 1.44 sec)
# Dec 10 09:08:39.775 [INFO] my_cifar_run accumulated 5664 samples for epoch #19 from 2 peers. ETA 2.48 sec (refresh in 0.99 sec)
# Dec 10 09:08:40.963 [INFO] my_cifar_run accumulated 6848 samples for epoch #19 from 2 peers. ETA 1.76 sec (refresh in 0.70 sec)
# Dec 10 09:08:41.875 [INFO] my_cifar_run accumulated 7552 samples for epoch #19 from 2 peers. ETA 1.55 sec (refresh in 0.62 sec)
# Dec 10 09:08:42.692 [INFO] my_cifar_run accumulated 8064 samples for epoch #19 from 2 peers. ETA 1.34 sec (refresh in 0.54 sec)
# Dec 10 09:08:43.425 [INFO] my_cifar_run accumulated 8544 samples for epoch #19 from 2 peers. ETA 0.95 sec (refresh in 0.50 sec)
# Dec 10 09:08:44.141 [INFO] my_cifar_run accumulated 9024 samples for epoch #19 from 2 peers. ETA 0.59 sec (refresh in 0.50 sec)
# Dec 10 09:08:44.838 [INFO] my_cifar_run accumulated 9472 samples for epoch #19 from 2 peers. ETA 0.29 sec (refresh in 0.50 sec)
# Dec 10 09:08:44.850 [INFO] Transitioning to epoch 20
# Dec 10 09:08:44.908 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:08:45.570 [INFO] my_cifar_run accumulated 32 samples for epoch #20 from 2 peers. ETA 7.20 sec (refresh in 2.88 sec)
# Dec 10 09:08:48.644 [INFO] my_cifar_run accumulated 32 samples for epoch #20 from 2 peers. ETA 5.81 sec (refresh in 2.32 sec)
# Dec 10 09:08:51.163 [INFO] my_cifar_run accumulated 32 samples for epoch #20 from 2 peers. ETA 4.67 sec (refresh in 1.87 sec)
# Dec 10 09:08:53.223 [INFO] my_cifar_run accumulated 32 samples for epoch #20 from 2 peers. ETA 3.73 sec (refresh in 1.49 sec)
# Dec 10 09:08:54.859 [INFO] Averaging failed with <class 'concurrent.futures._base.TimeoutError'>
# Dec 10 09:08:54.862 [INFO] Received parameters from background averaging round
# Dec 10 09:08:54.912 [INFO] my_cifar_run accumulated 32 samples for epoch #20 from 2 peers. ETA 2.97 sec (refresh in 1.19 sec)
# Dec 10 09:08:55.228 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:08:56.308 [INFO] my_cifar_run accumulated 1024 samples for epoch #20 from 2 peers. ETA 8.15 sec (refresh in 3.26 sec)
# Dec 10 09:08:59.773 [INFO] my_cifar_run accumulated 3232 samples for epoch #20 from 2 peers. ETA 4.92 sec (refresh in 1.97 sec)
# Dec 10 09:09:01.953 [INFO] my_cifar_run accumulated 4928 samples for epoch #20 from 2 peers. ETA 2.98 sec (refresh in 1.19 sec)
# Dec 10 09:09:03.379 [INFO] my_cifar_run accumulated 6336 samples for epoch #20 from 2 peers. ETA 1.94 sec (refresh in 0.77 sec)
# Dec 10 09:09:04.355 [INFO] my_cifar_run accumulated 7296 samples for epoch #20 from 2 peers. ETA 1.43 sec (refresh in 0.57 sec)
# Dec 10 09:09:05.131 [INFO] my_cifar_run accumulated 8000 samples for epoch #20 from 2 peers. ETA 1.06 sec (refresh in 0.50 sec)
# Dec 10 09:09:05.831 [INFO] my_cifar_run accumulated 8672 samples for epoch #20 from 2 peers. ETA 0.69 sec (refresh in 0.50 sec)
# Dec 10 09:09:06.529 [INFO] my_cifar_run accumulated 9344 samples for epoch #20 from 2 peers. ETA 0.26 sec (refresh in 0.50 sec)
# Dec 10 09:09:06.813 [INFO] Transitioning to epoch 21
# Dec 10 09:09:06.858 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:09:07.227 [INFO] my_cifar_run accumulated 32 samples for epoch #21 from 2 peers. ETA 5.86 sec (refresh in 2.34 sec)
# Dec 10 09:09:09.767 [INFO] my_cifar_run accumulated 32 samples for epoch #21 from 2 peers. ETA 4.44 sec (refresh in 1.78 sec)
# Dec 10 09:09:11.739 [INFO] my_cifar_run accumulated 32 samples for epoch #21 from 2 peers. ETA 3.34 sec (refresh in 1.34 sec)
# Dec 10 09:09:13.271 [INFO] my_cifar_run accumulated 32 samples for epoch #21 from 2 peers. ETA 2.48 sec (refresh in 0.99 sec)
# Dec 10 09:09:14.458 [INFO] my_cifar_run accumulated 32 samples for epoch #21 from 2 peers. ETA 1.82 sec (refresh in 0.73 sec)
# Dec 10 09:09:15.380 [INFO] my_cifar_run accumulated 32 samples for epoch #21 from 2 peers. ETA 1.31 sec (refresh in 0.52 sec)
# Dec 10 09:09:16.095 [INFO] my_cifar_run accumulated 32 samples for epoch #21 from 2 peers. ETA 0.91 sec (refresh in 0.50 sec)
# Dec 10 09:09:16.787 [INFO] my_cifar_run accumulated 32 samples for epoch #21 from 2 peers. ETA 0.52 sec (refresh in 0.50 sec)
# Dec 10 09:09:16.828 [INFO] Averaging failed with <class 'concurrent.futures._base.TimeoutError'>
# Dec 10 09:09:16.832 [INFO] Received parameters from background averaging round
# Dec 10 09:09:17.206 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:09:17.486 [INFO] my_cifar_run accumulated 480 samples for epoch #21 from 2 peers. ETA 11.33 sec (refresh in 4.53 sec)
# Dec 10 09:09:17.490 [INFO] Transitioning to epoch 22
# Dec 10 09:09:17.548 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:09:22.215 [INFO] my_cifar_run accumulated 32 samples for epoch #22 from 1 peers. ETA 63.62 sec (refresh in 10.00 sec)
# Dec 10 09:09:27.513 [INFO] Averaging failed with <class 'concurrent.futures._base.TimeoutError'>
# Dec 10 09:09:27.516 [INFO] Received parameters from background averaging round
# Dec 10 09:09:27.885 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:09:32.438 [INFO] my_cifar_run accumulated 8768 samples for epoch #22 from 2 peers. ETA 0.64 sec (refresh in 0.50 sec)
# Dec 10 09:09:33.145 [INFO] my_cifar_run accumulated 9696 samples for epoch #22 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:09:33.147 [INFO] Transitioning to epoch 23
# Dec 10 09:09:33.209 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:09:33.845 [INFO] my_cifar_run accumulated 32 samples for epoch #23 from 2 peers. ETA 7.43 sec (refresh in 2.97 sec)
# Dec 10 09:09:37.019 [INFO] my_cifar_run accumulated 1408 samples for epoch #23 from 2 peers. ETA 3.59 sec (refresh in 1.43 sec)
# Dec 10 09:09:38.659 [INFO] my_cifar_run accumulated 2432 samples for epoch #23 from 2 peers. ETA 1.92 sec (refresh in 0.77 sec)
# Dec 10 09:09:39.626 [INFO] my_cifar_run accumulated 3104 samples for epoch #23 from 2 peers. ETA 0.97 sec (refresh in 0.50 sec)
# Dec 10 09:09:40.323 [INFO] my_cifar_run accumulated 3552 samples for epoch #23 from 2 peers. ETA 0.30 sec (refresh in 0.50 sec)
# Dec 10 09:09:41.018 [INFO] my_cifar_run accumulated 32 samples for epoch #24 from 2 peers. ETA 6.70 sec (refresh in 2.68 sec)
# Dec 10 09:09:42.899 [INFO] Averaged parameters with 2 peers
# Dec 10 09:09:42.902 [INFO] Received parameters from background averaging round
# Dec 10 09:09:42.908 [INFO] Transitioning to epoch 24
# Dec 10 09:09:42.959 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:09:43.902 [INFO] my_cifar_run accumulated 480 samples for epoch #24 from 2 peers. ETA 7.95 sec (refresh in 3.18 sec)
# Dec 10 09:09:47.289 [INFO] my_cifar_run accumulated 2592 samples for epoch #24 from 2 peers. ETA 2.82 sec (refresh in 1.13 sec)
# Dec 10 09:09:48.614 [INFO] my_cifar_run accumulated 3296 samples for epoch #24 from 2 peers. ETA 1.56 sec (refresh in 0.62 sec)
# Dec 10 09:09:49.442 [INFO] my_cifar_run accumulated 3648 samples for epoch #24 from 2 peers. ETA 0.78 sec (refresh in 0.50 sec)
# Dec 10 09:09:50.150 [INFO] my_cifar_run accumulated 4032 samples for epoch #24 from 2 peers. ETA 0.04 sec (refresh in 0.50 sec)
# Dec 10 09:09:50.851 [INFO] my_cifar_run accumulated 32 samples for epoch #25 from 2 peers. ETA 7.71 sec (refresh in 3.08 sec)
# Dec 10 09:09:52.830 [INFO] Averaged parameters with 2 peers
# Dec 10 09:09:52.833 [INFO] Received parameters from background averaging round
# Dec 10 09:09:52.838 [INFO] Transitioning to epoch 25
# Dec 10 09:09:52.881 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:09:54.138 [INFO] my_cifar_run accumulated 800 samples for epoch #25 from 2 peers. ETA 6.35 sec (refresh in 2.54 sec)
# Dec 10 09:09:56.879 [INFO] my_cifar_run accumulated 2592 samples for epoch #25 from 2 peers. ETA 2.81 sec (refresh in 1.12 sec)
# Dec 10 09:09:58.213 [INFO] my_cifar_run accumulated 3520 samples for epoch #25 from 2 peers. ETA 1.26 sec (refresh in 0.50 sec)
# Dec 10 09:09:58.934 [INFO] my_cifar_run accumulated 3968 samples for epoch #25 from 2 peers. ETA 0.67 sec (refresh in 0.50 sec)
# Dec 10 09:09:59.639 [INFO] my_cifar_run accumulated 4480 samples for epoch #25 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:10:00.338 [INFO] my_cifar_run accumulated 32 samples for epoch #26 from 2 peers. ETA 6.25 sec (refresh in 2.50 sec)
# Dec 10 09:10:02.589 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:02.591 [INFO] Received parameters from background averaging round
# Dec 10 09:10:02.595 [INFO] Transitioning to epoch 26
# Dec 10 09:10:02.683 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:03.071 [INFO] my_cifar_run accumulated 160 samples for epoch #26 from 2 peers. ETA 11.28 sec (refresh in 4.51 sec)
# Dec 10 09:10:07.776 [INFO] my_cifar_run accumulated 2880 samples for epoch #26 from 2 peers. ETA 2.30 sec (refresh in 0.92 sec)
# Dec 10 09:10:08.896 [INFO] my_cifar_run accumulated 3616 samples for epoch #26 from 2 peers. ETA 1.15 sec (refresh in 0.50 sec)
# Dec 10 09:10:09.597 [INFO] my_cifar_run accumulated 4064 samples for epoch #26 from 2 peers. ETA 0.50 sec (refresh in 0.50 sec)
# Dec 10 09:10:10.292 [INFO] my_cifar_run accumulated 4512 samples for epoch #26 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:10:10.989 [INFO] my_cifar_run accumulated 32 samples for epoch #27 from 2 peers. ETA 7.14 sec (refresh in 2.86 sec)
# Dec 10 09:10:12.391 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:12.397 [INFO] Received parameters from background averaging round
# Dec 10 09:10:12.399 [INFO] Transitioning to epoch 27
# Dec 10 09:10:12.455 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:14.070 [INFO] my_cifar_run accumulated 928 samples for epoch #27 from 2 peers. ETA 6.22 sec (refresh in 2.49 sec)
# Dec 10 09:10:16.763 [INFO] my_cifar_run accumulated 2368 samples for epoch #27 from 2 peers. ETA 3.66 sec (refresh in 1.46 sec)
# Dec 10 09:10:18.432 [INFO] my_cifar_run accumulated 3200 samples for epoch #27 from 2 peers. ETA 1.88 sec (refresh in 0.75 sec)
# Dec 10 09:10:19.381 [INFO] my_cifar_run accumulated 3648 samples for epoch #27 from 2 peers. ETA 1.00 sec (refresh in 0.50 sec)
# Dec 10 09:10:20.095 [INFO] my_cifar_run accumulated 4000 samples for epoch #27 from 2 peers. ETA 0.26 sec (refresh in 0.50 sec)
# Dec 10 09:10:20.803 [INFO] my_cifar_run accumulated 0 samples for epoch #28 from 2 peers. ETA 8.51 sec (refresh in 3.40 sec)
# Dec 10 09:10:22.034 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:22.036 [INFO] Received parameters from background averaging round
# Dec 10 09:10:22.052 [INFO] Transitioning to epoch 28
# Dec 10 09:10:22.091 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:24.408 [INFO] my_cifar_run accumulated 1408 samples for epoch #28 from 2 peers. ETA 4.91 sec (refresh in 1.97 sec)
# Dec 10 09:10:26.575 [INFO] my_cifar_run accumulated 2816 samples for epoch #28 from 2 peers. ETA 2.66 sec (refresh in 1.06 sec)
# Dec 10 09:10:27.849 [INFO] my_cifar_run accumulated 3712 samples for epoch #28 from 2 peers. ETA 1.32 sec (refresh in 0.53 sec)
# Dec 10 09:10:28.588 [INFO] my_cifar_run accumulated 4192 samples for epoch #28 from 2 peers. ETA 0.59 sec (refresh in 0.50 sec)
# Dec 10 09:10:29.291 [INFO] my_cifar_run accumulated 4672 samples for epoch #28 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:10:29.988 [INFO] my_cifar_run accumulated 32 samples for epoch #29 from 2 peers. ETA 6.99 sec (refresh in 2.80 sec)
# Dec 10 09:10:31.820 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:31.823 [INFO] Received parameters from background averaging round
# Dec 10 09:10:31.836 [INFO] Transitioning to epoch 29
# Dec 10 09:10:31.885 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:32.979 [INFO] my_cifar_run accumulated 448 samples for epoch #29 from 2 peers. ETA 9.04 sec (refresh in 3.61 sec)
# Dec 10 09:10:36.789 [INFO] my_cifar_run accumulated 2496 samples for epoch #29 from 2 peers. ETA 2.62 sec (refresh in 1.05 sec)
# Dec 10 09:10:38.047 [INFO] my_cifar_run accumulated 3328 samples for epoch #29 from 2 peers. ETA 1.36 sec (refresh in 0.54 sec)
# Dec 10 09:10:38.787 [INFO] my_cifar_run accumulated 3840 samples for epoch #29 from 2 peers. ETA 0.61 sec (refresh in 0.50 sec)
# Dec 10 09:10:39.483 [INFO] my_cifar_run accumulated 4288 samples for epoch #29 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:10:40.179 [INFO] my_cifar_run accumulated 32 samples for epoch #30 from 2 peers. ETA 7.00 sec (refresh in 2.80 sec)
# Dec 10 09:10:41.609 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:41.612 [INFO] Received parameters from background averaging round
# Dec 10 09:10:41.625 [INFO] Transitioning to epoch 30
# Dec 10 09:10:41.687 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:43.197 [INFO] my_cifar_run accumulated 864 samples for epoch #30 from 2 peers. ETA 6.42 sec (refresh in 2.57 sec)
# Dec 10 09:10:45.967 [INFO] my_cifar_run accumulated 2624 samples for epoch #30 from 2 peers. ETA 3.18 sec (refresh in 1.27 sec)
# Dec 10 09:10:47.440 [INFO] my_cifar_run accumulated 3392 samples for epoch #30 from 2 peers. ETA 1.96 sec (refresh in 0.78 sec)
# Dec 10 09:10:48.438 [INFO] my_cifar_run accumulated 3840 samples for epoch #30 from 2 peers. ETA 1.03 sec (refresh in 0.50 sec)
# Dec 10 09:10:49.154 [INFO] my_cifar_run accumulated 4192 samples for epoch #30 from 2 peers. ETA 0.31 sec (refresh in 0.50 sec)
# Dec 10 09:10:49.871 [INFO] my_cifar_run accumulated 0 samples for epoch #31 from 2 peers. ETA 8.25 sec (refresh in 3.30 sec)
# Dec 10 09:10:51.383 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:51.390 [INFO] Received parameters from background averaging round
# Dec 10 09:10:51.399 [INFO] Transitioning to epoch 31
# Dec 10 09:10:51.462 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:53.373 [INFO] my_cifar_run accumulated 1216 samples for epoch #31 from 2 peers. ETA 5.61 sec (refresh in 2.25 sec)
# Dec 10 09:10:55.820 [INFO] my_cifar_run accumulated 2816 samples for epoch #31 from 2 peers. ETA 2.90 sec (refresh in 1.16 sec)
# Dec 10 09:10:57.181 [INFO] my_cifar_run accumulated 3744 samples for epoch #31 from 2 peers. ETA 1.43 sec (refresh in 0.57 sec)
# Dec 10 09:10:57.961 [INFO] my_cifar_run accumulated 4224 samples for epoch #31 from 2 peers. ETA 0.73 sec (refresh in 0.50 sec)
# Dec 10 09:10:58.656 [INFO] my_cifar_run accumulated 4672 samples for epoch #31 from 2 peers. ETA 0.06 sec (refresh in 0.50 sec)
# Dec 10 09:10:59.351 [INFO] my_cifar_run accumulated 32 samples for epoch #32 from 2 peers. ETA 6.91 sec (refresh in 2.76 sec)
# Dec 10 09:11:01.146 [INFO] Averaged parameters with 2 peers
# Dec 10 09:11:01.150 [INFO] Received parameters from background averaging round
# Dec 10 09:11:01.153 [INFO] Transitioning to epoch 32
# Dec 10 09:11:01.211 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:11:02.314 [INFO] my_cifar_run accumulated 416 samples for epoch #32 from 2 peers. ETA 9.68 sec (refresh in 3.87 sec)
# Dec 10 09:11:06.392 [INFO] my_cifar_run accumulated 2464 samples for epoch #32 from 2 peers. ETA 3.02 sec (refresh in 1.21 sec)
# Dec 10 09:11:07.799 [INFO] my_cifar_run accumulated 3392 samples for epoch #32 from 2 peers. ETA 1.37 sec (refresh in 0.55 sec)
# Dec 10 09:11:08.545 [INFO] my_cifar_run accumulated 3872 samples for epoch #32 from 2 peers. ETA 0.68 sec (refresh in 0.50 sec)
# Dec 10 09:11:09.243 [INFO] my_cifar_run accumulated 4352 samples for epoch #32 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:11:09.937 [INFO] my_cifar_run accumulated 32 samples for epoch #33 from 2 peers. ETA 7.31 sec (refresh in 2.92 sec)
# Dec 10 09:11:10.806 [INFO] Averaged parameters with 2 peers
# Dec 10 09:11:10.809 [INFO] Received parameters from background averaging round
# Dec 10 09:11:10.815 [INFO] Transitioning to epoch 33
# Dec 10 09:11:10.864 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:11:13.056 [INFO] my_cifar_run accumulated 96 samples for epoch #33 from 2 peers. ETA 9.53 sec (refresh in 3.81 sec)
# Dec 10 09:11:17.066 [INFO] my_cifar_run accumulated 96 samples for epoch #33 from 2 peers. ETA 5.52 sec (refresh in 2.21 sec)
# Dec 10 09:11:19.472 [INFO] my_cifar_run accumulated 96 samples for epoch #33 from 2 peers. ETA 3.12 sec (refresh in 1.25 sec)
# Dec 10 09:11:20.842 [INFO] Averaging failed with <class 'concurrent.futures._base.TimeoutError'>
# Dec 10 09:11:20.846 [INFO] Received parameters from background averaging round
# Dec 10 09:11:20.916 [INFO] my_cifar_run accumulated 96 samples for epoch #33 from 2 peers. ETA 1.67 sec (refresh in 0.67 sec)
# Dec 10 09:11:21.216 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:11:21.793 [INFO] my_cifar_run accumulated 736 samples for epoch #33 from 2 peers. ETA 22.05 sec (refresh in 8.82 sec)
# Dec 10 09:11:30.827 [INFO] my_cifar_run accumulated 8832 samples for epoch #33 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:11:30.852 [INFO] Transitioning to epoch 34
# Dec 10 09:11:30.921 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:11:31.524 [INFO] my_cifar_run accumulated 32 samples for epoch #34 from 2 peers. ETA 9.59 sec (refresh in 3.84 sec)
# Dec 10 09:11:35.559 [INFO] my_cifar_run accumulated 32 samples for epoch #34 from 2 peers. ETA 6.20 sec (refresh in 2.48 sec)
# Dec 10 09:11:38.236 [INFO] my_cifar_run accumulated 32 samples for epoch #34 from 2 peers. ETA 3.95 sec (refresh in 1.58 sec)
# Dec 10 09:11:40.044 [INFO] my_cifar_run accumulated 32 samples for epoch #34 from 2 peers. ETA 2.42 sec (refresh in 0.97 sec)
# Dec 10 09:11:40.868 [INFO] Averaging failed with <class 'concurrent.futures._base.TimeoutError'>
# Dec 10 09:11:40.872 [INFO] Received parameters from background averaging round
# Dec 10 09:11:41.238 [INFO] my_cifar_run accumulated 160 samples for epoch #34 from 2 peers. ETA 49.46 sec (refresh in 10.00 sec)
# Dec 10 09:11:41.263 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:11:51.490 [INFO] my_cifar_run accumulated 7936 samples for epoch #34 from 2 peers. ETA 1.73 sec (refresh in 0.69 sec)
# Dec 10 09:11:52.395 [INFO] my_cifar_run accumulated 8736 samples for epoch #34 from 2 peers. ETA 1.00 sec (refresh in 0.50 sec)
# Dec 10 09:11:53.094 [INFO] my_cifar_run accumulated 9344 samples for epoch #34 from 2 peers. ETA 0.47 sec (refresh in 0.50 sec)
# Dec 10 09:11:53.577 [INFO] Transitioning to epoch 35
# Dec 10 09:11:53.640 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:11:53.883 [INFO] my_cifar_run accumulated 0 samples for epoch #35 from 2 peers. ETA 9.84 sec (refresh in 3.93 sec)
# Dec 10 09:11:58.014 [INFO] my_cifar_run accumulated 32 samples for epoch #35 from 2 peers. ETA 6.17 sec (refresh in 2.47 sec)
# Dec 10 09:12:00.694 [INFO] my_cifar_run accumulated 32 samples for epoch #35 from 2 peers. ETA 3.91 sec (refresh in 1.56 sec)
# Dec 10 09:12:02.453 [INFO] my_cifar_run accumulated 32 samples for epoch #35 from 2 peers. ETA 2.42 sec (refresh in 0.97 sec)
# Dec 10 09:12:03.600 [INFO] Averaging failed with <class 'concurrent.futures._base.TimeoutError'>
# Dec 10 09:12:03.603 [INFO] Received parameters from background averaging round
# Dec 10 09:12:03.622 [INFO] my_cifar_run accumulated 32 samples for epoch #35 from 2 peers. ETA 1.44 sec (refresh in 0.57 sec)
# Dec 10 09:12:03.967 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:12:04.393 [INFO] my_cifar_run accumulated 576 samples for epoch #35 from 2 peers. ETA 31.11 sec (refresh in 10.00 sec)
# Dec 10 09:12:14.604 [INFO] my_cifar_run accumulated 8928 samples for epoch #35 from 2 peers. ETA 1.17 sec (refresh in 0.50 sec)
# Dec 10 09:12:15.333 [INFO] my_cifar_run accumulated 9312 samples for epoch #35 from 2 peers. ETA 0.76 sec (refresh in 0.50 sec)
# Dec 10 09:12:16.078 [INFO] my_cifar_run accumulated 9728 samples for epoch #35 from 2 peers. ETA 0.20 sec (refresh in 0.50 sec)
# Dec 10 09:12:16.290 [INFO] Transitioning to epoch 36
# Dec 10 09:12:16.362 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:12:16.771 [INFO] my_cifar_run accumulated 32 samples for epoch #36 from 2 peers. ETA 13.70 sec (refresh in 5.48 sec)
# Dec 10 09:12:23.032 [INFO] my_cifar_run accumulated 32 samples for epoch #36 from 1 peers. ETA 11.32 sec (refresh in 2.83 sec)
# Dec 10 09:12:26.066 [INFO] my_cifar_run accumulated 2272 samples for epoch #36 from 2 peers. ETA 1.68 sec (refresh in 0.67 sec)
# Dec 10 09:12:26.305 [INFO] Averaging failed with <class 'concurrent.futures._base.TimeoutError'>
# Dec 10 09:12:26.310 [INFO] Received parameters from background averaging round
# Dec 10 09:12:26.712 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:12:27.015 [INFO] my_cifar_run accumulated 3200 samples for epoch #36 from 2 peers. ETA 8.04 sec (refresh in 3.22 sec)
# Dec 10 09:12:30.458 [INFO] my_cifar_run accumulated 7360 samples for epoch #36 from 2 peers. ETA 2.02 sec (refresh in 0.81 sec)
# Dec 10 09:12:31.532 [INFO] my_cifar_run accumulated 8544 samples for epoch #36 from 2 peers. ETA 0.86 sec (refresh in 0.50 sec)
# Dec 10 09:12:32.241 [INFO] my_cifar_run accumulated 9440 samples for epoch #36 from 2 peers. ETA 0.17 sec (refresh in 0.50 sec)
# Dec 10 09:12:32.439 [INFO] Transitioning to epoch 37
# Dec 10 09:12:32.501 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:12:32.941 [INFO] my_cifar_run accumulated 64 samples for epoch #37 from 2 peers. ETA 7.83 sec (refresh in 3.13 sec)
# Dec 10 09:12:36.196 [INFO] Averaged parameters with 2 peers
# Dec 10 09:12:36.200 [INFO] Received parameters from background averaging round
# Dec 10 09:12:36.284 [INFO] my_cifar_run accumulated 64 samples for epoch #37 from 2 peers. ETA 4.49 sec (refresh in 1.80 sec)
# Dec 10 09:12:38.353 [INFO] my_cifar_run accumulated 2784 samples for epoch #37 from 2 peers. ETA 5.08 sec (refresh in 2.03 sec)
# Dec 10 09:12:40.629 [INFO] my_cifar_run accumulated 6016 samples for epoch #37 from 2 peers. ETA 2.42 sec (refresh in 0.97 sec)
# Dec 10 09:12:41.808 [INFO] my_cifar_run accumulated 7680 samples for epoch #37 from 2 peers. ETA 1.34 sec (refresh in 0.54 sec)
# Dec 10 09:12:42.564 [INFO] my_cifar_run accumulated 8672 samples for epoch #37 from 2 peers. ETA 0.69 sec (refresh in 0.50 sec)
# Dec 10 09:12:43.274 [INFO] my_cifar_run accumulated 9504 samples for epoch #37 from 2 peers. ETA 0.10 sec (refresh in 0.50 sec)
# Dec 10 09:12:43.391 [INFO] Transitioning to epoch 38
# Dec 10 09:12:43.504 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:12:43.972 [INFO] my_cifar_run accumulated 64 samples for epoch #38 from 2 peers. ETA 8.13 sec (refresh in 3.25 sec)
# Dec 10 09:12:47.064 [INFO] Averaged parameters with 2 peers
# Dec 10 09:12:47.074 [INFO] Received parameters from background averaging round
# Dec 10 09:12:47.752 [INFO] my_cifar_run accumulated 352 samples for epoch #38 from 2 peers. ETA 45.45 sec (refresh in 10.00 sec)
# Dec 10 09:12:58.551 [INFO] my_cifar_run accumulated 32 samples for epoch #39 from 2 peers. ETA 8.23 sec (refresh in 3.29 sec)
# Dec 10 09:12:58.784 [INFO] Transitioning to epoch 39
# ...
# Dec 10 09:21:10.769 [INFO] my_cifar_run accumulated 32 samples for epoch #79 from 2 peers. ETA 4.03 sec (refresh in 1.61 sec)
# Dec 10 09:21:12.390 [INFO] my_cifar_run accumulated 32 samples for epoch #79 from 2 peers. ETA 2.93 sec (refresh in 1.17 sec)
# Dec 10 09:21:13.568 [INFO] my_cifar_run accumulated 32 samples for epoch #79 from 2 peers. ETA 2.13 sec (refresh in 0.85 sec)
# Dec 10 09:21:14.429 [INFO] my_cifar_run accumulated 32 samples for epoch #79 from 2 peers. ETA 1.55 sec (refresh in 0.62 sec)
# Dec 10 09:21:15.036 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:21:15.040 [INFO] Averaging failed with <class 'hivemind.averaging.partition.AllreduceException'>
# Dec 10 09:21:15.044 [INFO] Received parameters from background averaging round
# Dec 10 09:21:15.061 [INFO] my_cifar_run accumulated 32 samples for epoch #79 from 2 peers. ETA 1.12 sec (refresh in 0.50 sec)
# Dec 10 09:21:15.566 [INFO] my_cifar_run accumulated 512 samples for epoch #79 from 2 peers. ETA 17.85 sec (refresh in 7.14 sec)
# Dec 10 09:21:22.711 [INFO] my_cifar_run accumulated 7968 samples for epoch #79 from 2 peers. ETA 1.40 sec (refresh in 0.56 sec)
# Dec 10 09:21:23.275 [INFO] my_cifar_run accumulated 8544 samples for epoch #79 from 2 peers. ETA 0.99 sec (refresh in 0.50 sec)
# Dec 10 09:21:23.801 [INFO] my_cifar_run accumulated 8992 samples for epoch #79 from 2 peers. ETA 0.78 sec (refresh in 0.50 sec)
# Dec 10 09:21:24.314 [INFO] my_cifar_run accumulated 9344 samples for epoch #79 from 2 peers. ETA 0.53 sec (refresh in 0.50 sec)
# Dec 10 09:21:24.821 [INFO] my_cifar_run accumulated 9728 samples for epoch #79 from 2 peers. ETA 0.21 sec (refresh in 0.50 sec)
# Dec 10 09:21:25.073 [INFO] Transitioning to epoch 80
# Dec 10 09:21:25.171 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:21:25.329 [INFO] my_cifar_run accumulated 32 samples for epoch #80 from 2 peers. ETA 9.01 sec (refresh in 3.61 sec)
# Dec 10 09:21:28.941 [INFO] my_cifar_run accumulated 32 samples for epoch #80 from 2 peers. ETA 6.76 sec (refresh in 2.70 sec)
# Dec 10 09:21:31.653 [INFO] my_cifar_run accumulated 32 samples for epoch #80 from 2 peers. ETA 5.06 sec (refresh in 2.02 sec)
# Dec 10 09:21:33.682 [INFO] my_cifar_run accumulated 32 samples for epoch #80 from 2 peers. ETA 3.79 sec (refresh in 1.52 sec)
# Dec 10 09:21:35.065 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:21:35.070 [INFO] Averaging failed with <class 'hivemind.averaging.partition.AllreduceException'>
# Dec 10 09:21:35.073 [INFO] Received parameters from background averaging round
# Dec 10 09:21:35.215 [INFO] my_cifar_run accumulated 160 samples for epoch #80 from 2 peers. ETA 21.80 sec (refresh in 8.72 sec)
# Dec 10 09:21:43.947 [INFO] my_cifar_run accumulated 7648 samples for epoch #80 from 2 peers. ETA 1.69 sec (refresh in 0.68 sec)
# Dec 10 09:21:44.632 [INFO] my_cifar_run accumulated 8320 samples for epoch #80 from 2 peers. ETA 1.21 sec (refresh in 0.50 sec)
# Dec 10 09:21:45.136 [INFO] my_cifar_run accumulated 8864 samples for epoch #80 from 2 peers. ETA 0.76 sec (refresh in 0.50 sec)
# Dec 10 09:21:45.647 [INFO] my_cifar_run accumulated 9376 samples for epoch #80 from 2 peers. ETA 0.42 sec (refresh in 0.50 sec)
# Dec 10 09:21:46.090 [INFO] Transitioning to epoch 81
# Dec 10 09:21:46.142 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:21:46.157 [INFO] my_cifar_run accumulated 32 samples for epoch #81 from 2 peers. ETA 7.12 sec (refresh in 2.85 sec)
# Dec 10 09:21:49.011 [INFO] my_cifar_run accumulated 32 samples for epoch #81 from 2 peers. ETA 5.10 sec (refresh in 2.04 sec)
# Dec 10 09:21:51.063 [INFO] my_cifar_run accumulated 32 samples for epoch #81 from 2 peers. ETA 3.65 sec (refresh in 1.46 sec)
# Dec 10 09:21:52.528 [INFO] my_cifar_run accumulated 32 samples for epoch #81 from 2 peers. ETA 2.61 sec (refresh in 1.04 sec)
# Dec 10 09:21:53.579 [INFO] my_cifar_run accumulated 32 samples for epoch #81 from 2 peers. ETA 1.87 sec (refresh in 0.75 sec)
# Dec 10 09:21:54.331 [INFO] my_cifar_run accumulated 32 samples for epoch #81 from 2 peers. ETA 1.34 sec (refresh in 0.53 sec)
# Dec 10 09:21:54.873 [INFO] my_cifar_run accumulated 32 samples for epoch #81 from 2 peers. ETA 0.95 sec (refresh in 0.50 sec)
# Dec 10 09:21:55.380 [INFO] my_cifar_run accumulated 32 samples for epoch #81 from 2 peers. ETA 0.59 sec (refresh in 0.50 sec)
# Dec 10 09:21:55.890 [INFO] my_cifar_run accumulated 32 samples for epoch #81 from 2 peers. ETA 0.23 sec (refresh in 0.50 sec)
# Dec 10 09:21:56.095 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:21:56.105 [INFO] Averaging failed with <class 'hivemind.averaging.partition.AllreduceException'>
# Dec 10 09:21:56.107 [INFO] Received parameters from background averaging round
# Dec 10 09:21:56.178 [INFO] Transitioning to epoch 82
# Dec 10 09:21:56.267 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:21:56.398 [INFO] my_cifar_run accumulated 32 samples for epoch #82 from 2 peers. ETA 22.46 sec (refresh in 8.98 sec)
# Dec 10 09:22:05.390 [INFO] my_cifar_run accumulated 32 samples for epoch #82 from 1 peers. ETA 282.43 sec (refresh in 10.00 sec)
# Dec 10 09:22:06.178 [ERROR] [hivemind.averaging.averager._step:480] Averaging step failed: could not find a group
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/hivemind/averaging/averager.py", line 450, in _step
#     raise AllreduceException("Averaging step failed: could not find a group")
# hivemind.averaging.partition.AllreduceException: Averaging step failed: could not find a group
# Dec 10 09:22:06.181 [INFO] Averaging failed with <class 'hivemind.averaging.partition.AllreduceException'>
# Dec 10 09:22:06.185 [INFO] Received parameters from background averaging round
# Dec 10 09:22:15.398 [INFO] my_cifar_run accumulated 8000 samples for epoch #82 from 1 peers. ETA 1.88 sec (refresh in 0.50 sec)
# Dec 10 09:22:15.903 [INFO] my_cifar_run accumulated 8480 samples for epoch #82 from 1 peers. ETA 1.45 sec (refresh in 0.50 sec)
# Dec 10 09:22:16.411 [INFO] my_cifar_run accumulated 9024 samples for epoch #82 from 1 peers. ETA 0.90 sec (refresh in 0.50 sec)
# Dec 10 09:22:16.916 [INFO] my_cifar_run accumulated 9536 samples for epoch #82 from 1 peers. ETA 0.42 sec (refresh in 0.50 sec)
# Dec 10 09:22:17.348 [INFO] Transitioning to epoch 83
# Dec 10 09:22:17.421 [INFO] my_cifar_run accumulated 64 samples for epoch #83 from 1 peers. ETA 9.38 sec (refresh in 2.35 sec)
# Dec 10 09:22:19.782 [INFO] my_cifar_run accumulated 2496 samples for epoch #83 from 1 peers. ETA 6.97 sec (refresh in 1.74 sec)
# Dec 10 09:22:21.530 [INFO] my_cifar_run accumulated 4320 samples for epoch #83 from 1 peers. ETA 5.58 sec (refresh in 1.40 sec)
# Dec 10 09:22:22.931 [INFO] my_cifar_run accumulated 5760 samples for epoch #83 from 1 peers. ETA 4.15 sec (refresh in 1.04 sec)
# Dec 10 09:22:23.986 [INFO] my_cifar_run accumulated 6560 samples for epoch #83 from 1 peers. ETA 4.58 sec (refresh in 1.15 sec)
# Dec 10 09:22:25.143 [INFO] my_cifar_run accumulated 7424 samples for epoch #83 from 1 peers. ETA 3.34 sec (refresh in 0.84 sec)
# Dec 10 09:22:25.992 [INFO] my_cifar_run accumulated 8032 samples for epoch #83 from 1 peers. ETA 2.59 sec (refresh in 0.65 sec)
# Dec 10 09:22:26.646 [INFO] my_cifar_run accumulated 8512 samples for epoch #83 from 1 peers. ETA 2.06 sec (refresh in 0.52 sec)
# Dec 10 09:22:27.166 [INFO] my_cifar_run accumulated 8864 samples for epoch #83 from 1 peers. ETA 1.60 sec (refresh in 0.50 sec)
# Dec 10 09:22:27.687 [INFO] my_cifar_run accumulated 9216 samples for epoch #83 from 1 peers. ETA 1.11 sec (refresh in 0.50 sec)
# Dec 10 09:22:28.191 [INFO] my_cifar_run accumulated 9696 samples for epoch #83 from 1 peers. ETA 0.32 sec (refresh in 0.50 sec)
# Dec 10 09:22:28.488 [INFO] Transitioning to epoch 84
# Dec 10 09:22:28.696 [INFO] my_cifar_run accumulated 160 samples for epoch #84 from 1 peers. ETA 10.45 sec (refresh in 2.61 sec)
# Dec 10 09:22:31.313 [INFO] my_cifar_run accumulated 2912 samples for epoch #84 from 1 peers. ETA 6.64 sec (refresh in 1.66 sec)
# Dec 10 09:22:32.979 [INFO] my_cifar_run accumulated 4608 samples for epoch #84 from 1 peers. ETA 5.05 sec (refresh in 1.26 sec)
# Dec 10 09:22:34.246 [INFO] my_cifar_run accumulated 5920 samples for epoch #84 from 1 peers. ETA 3.87 sec (refresh in 0.97 sec)
# Dec 10 09:22:35.217 [INFO] my_cifar_run accumulated 6944 samples for epoch #84 from 1 peers. ETA 2.81 sec (refresh in 0.70 sec)
# Dec 10 09:22:35.934 [INFO] my_cifar_run accumulated 7680 samples for epoch #84 from 1 peers. ETA 2.20 sec (refresh in 0.55 sec)
# Dec 10 09:22:36.490 [INFO] my_cifar_run accumulated 8224 samples for epoch #84 from 1 peers. ETA 1.78 sec (refresh in 0.50 sec)
# Dec 10 09:22:36.997 [INFO] my_cifar_run accumulated 8736 samples for epoch #84 from 1 peers. ETA 1.22 sec (refresh in 0.50 sec)
# Dec 10 09:22:37.505 [INFO] my_cifar_run accumulated 9248 samples for epoch #84 from 1 peers. ETA 0.71 sec (refresh in 0.50 sec)
# Dec 10 09:22:38.019 [INFO] my_cifar_run accumulated 9728 samples for epoch #84 from 1 peers. ETA 0.26 sec (refresh in 0.50 sec)
# Dec 10 09:22:38.326 [INFO] Transitioning to epoch 85
# Dec 10 09:22:38.528 [INFO] my_cifar_run accumulated 96 samples for epoch #85 from 1 peers. ETA 13.18 sec (refresh in 3.30 sec)
# Dec 10 09:22:41.833 [INFO] my_cifar_run accumulated 2496 samples for epoch #85 from 1 peers. ETA 10.50 sec (refresh in 2.62 sec)
# Dec 10 09:22:44.471 [INFO] my_cifar_run accumulated 5024 samples for epoch #85 from 1 peers. ETA 4.79 sec (refresh in 1.20 sec)
# Dec 10 09:22:45.688 [INFO] my_cifar_run accumulated 6208 samples for epoch #85 from 1 peers. ETA 3.72 sec (refresh in 0.93 sec)
# Dec 10 09:22:46.624 [INFO] my_cifar_run accumulated 7200 samples for epoch #85 from 1 peers. ETA 2.79 sec (refresh in 0.70 sec)
# Dec 10 09:22:47.326 [INFO] my_cifar_run accumulated 7936 samples for epoch #85 from 1 peers. ETA 1.95 sec (refresh in 0.50 sec)
# Dec 10 09:22:47.835 [INFO] my_cifar_run accumulated 8448 samples for epoch #85 from 1 peers. ETA 1.50 sec (refresh in 0.50 sec)
# Dec 10 09:22:48.342 [INFO] my_cifar_run accumulated 8992 samples for epoch #85 from 1 peers. ETA 0.98 sec (refresh in 0.50 sec)
# Dec 10 09:22:48.847 [INFO] my_cifar_run accumulated 9504 samples for epoch #85 from 1 peers. ETA 0.46 sec (refresh in 0.50 sec)
# Dec 10 09:22:49.334 [INFO] Transitioning to epoch 86
# Dec 10 09:22:49.364 [INFO] my_cifar_run accumulated 0 samples for epoch #86 from 1 peers. ETA 9.77 sec (refresh in 2.44 sec)
# Dec 10 09:22:51.817 [INFO] my_cifar_run accumulated 2528 samples for epoch #86 from 1 peers. ETA 7.28 sec (refresh in 1.82 sec)
# Dec 10 09:22:53.646 [INFO] my_cifar_run accumulated 4032 samples for epoch #86 from 1 peers. ETA 8.16 sec (refresh in 2.04 sec)
# Dec 10 09:22:55.690 [INFO] my_cifar_run accumulated 5504 samples for epoch #86 from 1 peers. ETA 6.36 sec (refresh in 1.59 sec)
# Dec 10 09:22:57.283 [INFO] my_cifar_run accumulated 6656 samples for epoch #86 from 1 peers. ETA 4.57 sec (refresh in 1.14 sec)
# Dec 10 09:22:58.432 [INFO] my_cifar_run accumulated 7712 samples for epoch #86 from 1 peers. ETA 2.19 sec (refresh in 0.55 sec)
# Dec 10 09:22:58.992 [INFO] my_cifar_run accumulated 8288 samples for epoch #86 from 1 peers. ETA 1.69 sec (refresh in 0.50 sec)
# Dec 10 09:22:59.499 [INFO] my_cifar_run accumulated 8800 samples for epoch #86 from 1 peers. ETA 1.17 sec (refresh in 0.50 sec)
# Dec 10 09:23:00.015 [INFO] my_cifar_run accumulated 9312 samples for epoch #86 from 1 peers. ETA 0.66 sec (refresh in 0.50 sec)
# Dec 10 09:23:00.529 [INFO] my_cifar_run accumulated 9824 samples for epoch #86 from 1 peers. ETA 0.14 sec (refresh in 0.50 sec)
# Dec 10 09:23:00.691 [INFO] Transitioning to epoch 87
# Dec 10 09:23:01.035 [INFO] my_cifar_run accumulated 320 samples for epoch #87 from 1 peers. ETA 9.42 sec (refresh in 2.36 sec)
# Dec 10 09:23:03.398 [INFO] my_cifar_run accumulated 2784 samples for epoch #87 from 1 peers. ETA 6.79 sec (refresh in 1.70 sec)
# Dec 10 09:23:05.112 [INFO] my_cifar_run accumulated 4288 samples for epoch #87 from 1 peers. ETA 6.97 sec (refresh in 1.74 sec)
# Dec 10 09:23:06.861 [INFO] my_cifar_run accumulated 5728 samples for epoch #87 from 1 peers. ETA 5.11 sec (refresh in 1.28 sec)
# Dec 10 09:23:08.169 [INFO] my_cifar_run accumulated 6656 samples for epoch #87 from 1 peers. ETA 4.79 sec (refresh in 1.20 sec)
# Dec 10 09:23:09.481 [INFO] my_cifar_run accumulated 6816 samples for epoch #87 from 1 peers. ETA 11.19 sec (refresh in 2.80 sec)
# Dec 10 09:23:12.313 [INFO] my_cifar_run accumulated 7456 samples for epoch #87 from 1 peers. ETA 8.87 sec (refresh in 2.22 sec)
# Dec 10 09:23:14.546 [INFO] my_cifar_run accumulated 8800 samples for epoch #87 from 1 peers. ETA 1.71 sec (refresh in 0.50 sec)
# Dec 10 09:23:15.060 [INFO] my_cifar_run accumulated 9184 samples for epoch #87 from 1 peers. ETA 1.05 sec (refresh in 0.50 sec)
# Dec 10 09:23:15.568 [INFO] my_cifar_run accumulated 9536 samples for epoch #87 from 1 peers. ETA 0.64 sec (refresh in 0.50 sec)
# Dec 10 09:23:16.094 [INFO] my_cifar_run accumulated 9888 samples for epoch #87 from 1 peers. ETA 0.14 sec (refresh in 0.50 sec)
# Dec 10 09:23:16.265 [INFO] Transitioning to epoch 88
# Dec 10 09:23:16.602 [INFO] my_cifar_run accumulated 224 samples for epoch #88 from 1 peers. ETA 13.61 sec (refresh in 3.40 sec)
# Dec 10 09:23:20.013 [INFO] my_cifar_run accumulated 3776 samples for epoch #88 from 1 peers. ETA 5.67 sec (refresh in 1.42 sec)
# Dec 10 09:23:21.436 [INFO] my_cifar_run accumulated 5248 samples for epoch #88 from 1 peers. ETA 4.53 sec (refresh in 1.13 sec)
# Dec 10 09:23:22.577 [INFO] my_cifar_run accumulated 6400 samples for epoch #88 from 1 peers. ETA 3.55 sec (refresh in 0.89 sec)
# Dec 10 09:23:23.480 [INFO] my_cifar_run accumulated 7360 samples for epoch #88 from 1 peers. ETA 2.51 sec (refresh in 0.63 sec)
# Dec 10 09:23:24.123 [INFO] my_cifar_run accumulated 8000 samples for epoch #88 from 1 peers. ETA 1.86 sec (refresh in 0.50 sec)
# Dec 10 09:23:24.630 [INFO] my_cifar_run accumulated 8512 samples for epoch #88 from 1 peers. ETA 1.47 sec (refresh in 0.50 sec)
# Dec 10 09:23:25.138 [INFO] my_cifar_run accumulated 9024 samples for epoch #88 from 1 peers. ETA 0.87 sec (refresh in 0.50 sec)
# Dec 10 09:23:25.643 [INFO] my_cifar_run accumulated 9536 samples for epoch #88 from 1 peers. ETA 0.44 sec (refresh in 0.50 sec)
# Dec 10 09:23:26.070 [INFO] Transitioning to epoch 89
# Dec 10 09:23:26.151 [INFO] my_cifar_run accumulated 64 samples for epoch #89 from 1 peers. ETA 9.49 sec (refresh in 2.37 sec)
# Dec 10 09:23:28.538 [INFO] my_cifar_run accumulated 1888 samples for epoch #89 from 1 peers. ETA 11.08 sec (refresh in 2.77 sec)
# Dec 10 09:23:31.317 [INFO] my_cifar_run accumulated 3840 samples for epoch #89 from 1 peers. ETA 8.86 sec (refresh in 2.21 sec)
# Dec 10 09:23:33.539 [INFO] my_cifar_run accumulated 6112 samples for epoch #89 from 1 peers. ETA 3.90 sec (refresh in 0.98 sec)
# Dec 10 09:23:34.526 [INFO] my_cifar_run accumulated 7104 samples for epoch #89 from 1 peers. ETA 2.86 sec (refresh in 0.72 sec)

# %% [markdown]
# To join the training, use initial_peers = ['/ip4/127.0.0.1/tcp/42905/p2p/12D3KooWSZVkzKhaTNAqohpaRbhXFGUbG18mbxczFktxLB4EEMwV']
