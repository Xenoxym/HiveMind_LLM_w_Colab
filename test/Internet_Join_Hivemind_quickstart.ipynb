# %%
# import requests

# # 使用第一个 COLAB 中提供的 ngrok 地址
# url = 'https://488e-34-168-54-187.ngrok-free.app'  # 请将 <ngrok_subdomain> 替换为实际地址

# response = requests.get(url)
# print(response.text)  # 输出来自第一个 COLAB 的响应

# %%
# !pip install torch==2.2.2
# !pip install torchvision==0.12.0
import torch
import torchvision
print(torch.__version__)
print(torchvision.__version__)
# Out:
# Collecting torch==2.2.2
#   Downloading torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.2.2) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.2)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.2)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.2)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.2)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.2)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.2)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.2)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.2)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.2)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.2)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.2)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch==2.2.2)
#   Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.2) (12.6.85)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.2.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.2.2) (1.3.0)
# Downloading torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 85.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 70.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 43.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.8 MB/s eta 0:00:00
# Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 7.6 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.6.0.74
#     Uninstalling nvidia-cudnn-cu12-9.6.0.74:
#       Successfully uninstalled nvidia-cudnn-cu12-9.6.0.74
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.2.2 which is incompatible.
# torchvision 0.20.1+cu121 requires torch==2.5.1, but you have torch 2.2.2 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvtx-cu12-12.1.105 torch-2.2.2 triton-2.2.0
# Collecting torchvision==0.12.0
#   Downloading torchvision-0.12.0-cp310-cp310-manylinux1_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (2.32.3)
# Collecting torch==1.11.0 (from torchvision==0.12.0)
#   Downloading torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (11.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (2024.8.30)
# Downloading torchvision-0.12.0-cp310-cp310-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 68.5 MB/s eta 0:00:00
# Downloading torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl (750.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 1.1 MB/s eta 0:00:00
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.2
#     Uninstalling torch-2.2.2:
#       Successfully uninstalled torch-2.2.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu121
#     Uninstalling torchvision-0.20.1+cu121:
#       Successfully uninstalled torchvision-0.20.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# peft 0.13.2 requires torch>=1.13.0, but you have torch 1.11.0 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 1.11.0 which is incompatible.
# Successfully installed torch-1.11.0 torchvision-0.12.0
# 1.11.0+cu102
# 0.12.0+cu102

# %%
import torch
import torchvision
print(torch.__version__)
print(torchvision.__version__)
# Out:
# 1.11.0+cu102
# 0.12.0+cu102

# %%
# %pip install -q petals

# %%
# !pip install hivemind
# Out:
# Collecting hivemind
#   Downloading hivemind-1.1.10.post2.tar.gz (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 5.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from hivemind) (6.0.2)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from hivemind) (1.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from hivemind) (1.26.4)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from hivemind) (1.13.1)
# Collecting prefetch_generator>=1.0.1 (from hivemind)
#   Downloading prefetch_generator-1.0.3.tar.gz (4.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from hivemind) (1.1.0)
# Collecting sortedcontainers (from hivemind)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting uvloop>=0.14.0 (from hivemind)
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting grpcio-tools>=1.33.2 (from hivemind)
#   Using cached grpcio_tools-1.68.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from hivemind) (4.25.5)
# Collecting configargparse>=1.2.3 (from hivemind)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl.metadata (23 kB)
# Collecting multiaddr>=0.0.9 (from hivemind)
#   Downloading multiaddr-0.0.9-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting pymultihash>=0.8.2 (from hivemind)
#   Downloading pymultihash-0.8.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: cryptography>=3.4.6 in /usr/local/lib/python3.10/dist-packages (from hivemind) (43.0.3)
# Collecting pydantic<2.0,>=1.8.1 (from hivemind)
#   Downloading pydantic-1.10.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.6/152.6 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from hivemind) (24.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.4.6->hivemind) (1.17.1)
# Collecting protobuf>=3.12.2 (from hivemind)
#   Using cached protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: grpcio>=1.68.1 in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.33.2->hivemind) (1.68.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.33.2->hivemind) (75.1.0)
# Collecting varint (from multiaddr>=0.0.9->hivemind)
#   Downloading varint-1.0.2.tar.gz (1.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from multiaddr>=0.0.9->hivemind) (1.16.0)
# Collecting base58 (from multiaddr>=0.0.9->hivemind)
#   Downloading base58-2.1.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting netaddr (from multiaddr>=0.0.9->hivemind)
#   Downloading netaddr-1.3.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.0,>=1.8.1->hivemind) (4.12.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.4.6->hivemind) (2.22)
# Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Using cached grpcio_tools-1.68.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
# Downloading multiaddr-0.0.9-py2.py3-none-any.whl (16 kB)
# Using cached protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading pydantic-1.10.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 42.9 MB/s eta 0:00:00
# Downloading pymultihash-0.8.2-py3-none-any.whl (13 kB)
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 78.7 MB/s eta 0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Downloading netaddr-1.3.0-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 74.6 MB/s eta 0:00:00
# Building wheels for collected packages: hivemind, prefetch_generator, varint
#   Building wheel for hivemind (pyproject.toml) ... done
#   Created wheel for hivemind: filename=hivemind-1.1.10.post2-py3-none-any.whl size=9012235 sha256=e90c84f285100c7c78ed7446928e2953ea7f935767f263bdae345949946282e8
#   Stored in directory: /root/.cache/pip/wheels/53/98/e3/d51ae54ae8302c5a1872fae2e85a8e8291651af19f550965c1
#   Building wheel for prefetch_generator (setup.py) ... done
#   Created wheel for prefetch_generator: filename=prefetch_generator-1.0.3-py3-none-any.whl size=4758 sha256=98636fd3c677607de4c7bb20ea0e37a220cea71832b758908035538e4de42776
#   Stored in directory: /root/.cache/pip/wheels/65/65/44/ed059bc23eeda93cfb19b58113423882cd9febae7ebf3f9ddf
#   Building wheel for varint (setup.py) ... done
#   Created wheel for varint: filename=varint-1.0.2-py3-none-any.whl size=1962 sha256=809b31806e4fe471f45a92ed90f5b2e06de67959e7ed918a030404f0de4b4fc5
#   Stored in directory: /root/.cache/pip/wheels/39/48/5e/33919c52a2a695a512ca394a5308dd12626a40bbcd288de814
# Successfully built hivemind prefetch_generator varint
# Installing collected packages: varint, sortedcontainers, pymultihash, prefetch_generator, uvloop, pydantic, protobuf, netaddr, configargparse, base58, multiaddr, grpcio-tools, hivemind
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.3
#     Uninstalling pydantic-2.10.3:
#       Successfully uninstalled pydantic-2.10.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.20 requires pydantic>=2.7.0, but you have pydantic 1.10.19 which is incompatible.
# langchain 0.3.9 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.19 which is incompatible.
# langchain-core 0.3.21 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 1.10.19 which is incompatible.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.
# Successfully installed base58-2.1.1 configargparse-1.7 grpcio-tools-1.68.1 hivemind-1.1.10.post2 multiaddr-0.0.9 netaddr-1.3.0 prefetch_generator-1.0.3 protobuf-5.29.1 pydantic-1.10.19 pymultihash-0.8.2 sortedcontainers-2.4.0 uvloop-0.21.0 varint-1.0.2

# %%
# import hivemind
# dht = hivemind.DHT(
#     host_maddrs=["/ip4/0.0.0.0/tcp/0", "/ip4/0.0.0.0/udp/0/quic"],
#     start=True)

# print('\n'.join(str(addr) for addr in dht.get_visible_maddrs()))
# print("Global IP:", hivemind.utils.networking.choose_ip_address(dht.get_visible_maddrs()))
# Out:
# /ip4/172.28.0.12/tcp/46403/p2p/12D3KooWBM5Nu3oyjSJY8QMYJALKs64bgB9M8dis1gT1ETN2qgwZ
# /ip4/127.0.0.1/tcp/46403/p2p/12D3KooWBM5Nu3oyjSJY8QMYJALKs64bgB9M8dis1gT1ETN2qgwZ
# /ip4/172.28.0.12/udp/42683/quic/p2p/12D3KooWBM5Nu3oyjSJY8QMYJALKs64bgB9M8dis1gT1ETN2qgwZ
# /ip4/127.0.0.1/udp/42683/quic/p2p/12D3KooWBM5Nu3oyjSJY8QMYJALKs64bgB9M8dis1gT1ETN2qgwZ
# Global IP: 172.28.0.12

# %%
# # ngrok
# !wget https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# !tar -xvzf ngrok-v3-stable-linux-amd64.tgz

# # ngrok authtoken
# !./ngrok authtoken 2q0WqdIL8HEbZMSU8CXwTFZrR5y_2A9nKPfF8zj8mC2tGkiF1
# Out:
# --2024-12-10 07:21:27--  https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# Resolving bin.equinox.io (bin.equinox.io)... 99.83.220.108, 35.71.179.82, 13.248.244.96, ...
# Connecting to bin.equinox.io (bin.equinox.io)|99.83.220.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14796857 (14M) [application/octet-stream]
# Saving to: ‘ngrok-v3-stable-linux-amd64.tgz’
#
# ngrok-v3-stable-lin 100%[===================>]  14.11M  65.0MB/s    in 0.2s
#
# 2024-12-10 07:21:27 (65.0 MB/s) - ‘ngrok-v3-stable-linux-amd64.tgz’ saved [14796857/14796857]
#
# ngrok
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import socket

# 输入你的 ngrok 公网地址
ngrok_host = "0.tcp.jp.ngrok.io"

# 获取 IP 地址
ip_address = socket.gethostbyname(ngrok_host)

# 输出 IP 地址
print(f"IP Address of {ngrok_host}: {ip_address}")
# Out:
# IP Address of 0.tcp.jp.ngrok.io: 13.115.131.56

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from tqdm.auto import tqdm

import hivemind

# Create dataset and model, same as in the basic tutorial
# For this basic tutorial, we download only the training set
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)

model = nn.Sequential(nn.Conv2d(3, 16, (5, 5)), nn.MaxPool2d(2, 2), nn.ReLU(),
                      nn.Conv2d(16, 32, (5, 5)), nn.MaxPool2d(2, 2), nn.ReLU(),
                      nn.Flatten(), nn.Linear(32 * 5 * 5, 10))
opt = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Create DHT: a decentralized key-value storage shared between peers

# dht = hivemind.DHT(start=True)

# dht = hivemind.DHT(
#     # host_maddrs=["/ip4/0.0.0.0/tcp/0", "/ip4/0.0.0.0/udp/0/quic"],
#     initial_peers=[
#         f"/ip4/{ip_address}/tcp/16497/p2p/12D3KooWBCdJnh6r7n4L4zxCd3iEofpNDbJKLXQ5gq1DqK6RYbcH",
#     ], start=True)

dht = hivemind.DHT(
    # host_maddrs=["/ip4/0.0.0.0/tcp/0", "/ip4/0.0.0.0/udp/0/quic"],
    initial_peers=[
        f"/ip4/35.76.159.227/tcp/15048/p2p/12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW",
    ], start=True)

# dht = hivemind.DHT(initial_peers=['/ip4/172.28.0.12/tcp/40987/p2p/12D3KooWPJGzNpLzZqoALePdwVaXsoSC4KK1dAmupZ3H7WcvbHJ9'], start=True)


print("To join the training, use initial_peers =", [str(addr) for addr in dht.get_visible_maddrs()])

# Set up a decentralized optimizer that will average with peers in background
opt = hivemind.Optimizer(
    dht=dht,                  # use a DHT that is connected with other peers
    run_id='my_cifar_run',    # unique identifier of this collaborative run
    batch_size_per_step=32,   # each call to opt.step adds this many samples towards the next epoch
    target_batch_size=10000,  # after peers collectively process this many samples, average weights and begin the next epoch
    optimizer=opt,            # wrap the SGD optimizer defined above
    use_local_updates=True,   # perform optimizer steps with local gradients, average parameters in background
    matchmaking_time=3.0,     # when averaging parameters, gather peers in background for up to this many seconds
    averaging_timeout=10.0,   # give up on averaging if not successful in this many seconds
    verbose=True              # print logs incessently
)

# # Note: if you intend to use GPU, switch to it only after the decentralized optimizer is created
# with tqdm() as progressbar:
#     while True:
#         for x_batch, y_batch in torch.utils.data.DataLoader(trainset, shuffle=True, batch_size=32):
#             opt.zero_grad()
#             loss = F.cross_entropy(model(x_batch), y_batch)
#             loss.backward()
#             opt.step()

#             progressbar.desc = f"loss = {loss.item():.3f}"
#             progressbar.update()


num_epochs = 1  # 设置你想要的 epoch 数
for epoch in range(num_epochs):
    with tqdm(total=len(trainset), desc=f"Epoch {epoch+1}/{num_epochs}") as progressbar:
        for x_batch, y_batch in torch.utils.data.DataLoader(trainset, shuffle=True, batch_size=32):
            opt.zero_grad()
            loss = F.cross_entropy(model(x_batch), y_batch)
            loss.backward()
            opt.step()

            progressbar.set_postfix(loss=loss.item())
            progressbar.update(len(x_batch))
# Out:
# Files already downloaded and verified
# Dec 10 09:09:21.569 [INFO] Sending goodbye to peers...
# Dec 10 09:09:21.581 [INFO] No longer fetching my_cifar_run_progress
# Dec 10 09:09:21.588 [INFO] No longer reporting progress for my_cifar_run
# Dec 10 09:09:21.599 [INFO] Shutting down averagers...
# Dec 10 09:09:21.634 [INFO] Optimizer is shut down
# To join the training, use initial_peers = ['/ip4/127.0.0.1/tcp/42553/p2p/12D3KooWHM8U9MEEikQDAugHRkv2RKUJ5fCMLbJXzJqHaVP2PJSd']
# Dec 10 09:09:23.392 [INFO] my_cifar_run accumulated 32 samples for epoch #22 from 1 peers. ETA 62.44 sec (refresh in 10.00 sec)
# Dec 10 09:09:23.400 [INFO] Initializing optimizer manually since it has no tensors in state dict. To override this, provide initialize_optimizer=False
# Dec 10 09:09:23.444 [WARN] [hivemind.averaging.matchmaking.__init__:54] It is recommended to use request_timeout smaller than min_matchmaking_time. Otherwise, matchmaking can cause deadlocks in some rare cases. Please see Matchmaking docstring.
# Epoch 1/1:   0%|          | 0/50000 [00:00<?, ?it/s]
# Dec 10 09:09:23.549 [INFO] Peer is out of sync
# Dec 10 09:09:23.745 [INFO] Downloading parameters from peer 12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW
# Dec 10 09:09:24.465 [INFO] Finished downloading state from 12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW
# Dec 10 09:09:33.589 [INFO] my_cifar_run accumulated 32 samples for epoch #23 from 2 peers. ETA 7.68 sec (refresh in 3.07 sec)
# Dec 10 09:09:33.608 [INFO] Peer is out of sync
# Dec 10 09:09:33.812 [INFO] Downloading parameters from peer 12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW
# Dec 10 09:09:34.083 [INFO] Finished downloading state from 12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW
# Dec 10 09:09:36.881 [INFO] my_cifar_run accumulated 1376 samples for epoch #23 from 2 peers. ETA 3.73 sec (refresh in 1.49 sec)
# Dec 10 09:09:38.597 [INFO] my_cifar_run accumulated 2496 samples for epoch #23 from 2 peers. ETA 2.02 sec (refresh in 0.81 sec)
# Dec 10 09:09:39.617 [INFO] my_cifar_run accumulated 3168 samples for epoch #23 from 2 peers. ETA 1.00 sec (refresh in 0.50 sec)
# Dec 10 09:09:40.323 [INFO] my_cifar_run accumulated 3584 samples for epoch #23 from 2 peers. ETA 0.31 sec (refresh in 0.50 sec)
# Dec 10 09:09:40.651 [INFO] Transitioning to epoch 24
# Dec 10 09:09:40.706 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:09:41.019 [INFO] my_cifar_run accumulated 32 samples for epoch #24 from 2 peers. ETA 6.70 sec (refresh in 2.68 sec)
# Dec 10 09:09:42.998 [INFO] Averaged parameters with 2 peers
# Dec 10 09:09:43.007 [INFO] Received parameters from background averaging round
# Dec 10 09:09:43.951 [INFO] my_cifar_run accumulated 576 samples for epoch #24 from 2 peers. ETA 7.43 sec (refresh in 2.97 sec)
# Dec 10 09:09:47.155 [INFO] my_cifar_run accumulated 2560 samples for epoch #24 from 2 peers. ETA 2.98 sec (refresh in 1.19 sec)
# Dec 10 09:09:48.553 [INFO] my_cifar_run accumulated 3296 samples for epoch #24 from 2 peers. ETA 1.62 sec (refresh in 0.65 sec)
# Dec 10 09:09:49.422 [INFO] my_cifar_run accumulated 3680 samples for epoch #24 from 2 peers. ETA 0.79 sec (refresh in 0.50 sec)
# Dec 10 09:09:50.147 [INFO] my_cifar_run accumulated 4064 samples for epoch #24 from 2 peers. ETA 0.05 sec (refresh in 0.50 sec)
# Dec 10 09:09:50.237 [INFO] Transitioning to epoch 25
# Dec 10 09:09:50.314 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:09:50.854 [INFO] my_cifar_run accumulated 32 samples for epoch #25 from 2 peers. ETA 7.71 sec (refresh in 3.08 sec)
# Dec 10 09:09:52.834 [INFO] Averaged parameters with 2 peers
# Dec 10 09:09:52.838 [INFO] Received parameters from background averaging round
# Dec 10 09:09:54.136 [INFO] my_cifar_run accumulated 864 samples for epoch #25 from 2 peers. ETA 6.22 sec (refresh in 2.49 sec)
# Dec 10 09:09:56.833 [INFO] my_cifar_run accumulated 2624 samples for epoch #25 from 2 peers. ETA 2.85 sec (refresh in 1.14 sec)
# Dec 10 09:09:58.189 [INFO] my_cifar_run accumulated 3584 samples for epoch #25 from 2 peers. ETA 1.30 sec (refresh in 0.52 sec)
# Dec 10 09:09:58.915 [INFO] my_cifar_run accumulated 4032 samples for epoch #25 from 2 peers. ETA 0.67 sec (refresh in 0.50 sec)
# Dec 10 09:09:59.620 [INFO] my_cifar_run accumulated 4544 samples for epoch #25 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:09:59.628 [INFO] Transitioning to epoch 26
# Dec 10 09:09:59.687 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:00.314 [INFO] my_cifar_run accumulated 32 samples for epoch #26 from 2 peers. ETA 6.26 sec (refresh in 2.50 sec)
# Dec 10 09:10:02.555 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:02.561 [INFO] Received parameters from background averaging round
# Dec 10 09:10:03.066 [INFO] my_cifar_run accumulated 160 samples for epoch #26 from 2 peers. ETA 11.28 sec (refresh in 4.51 sec)
# Dec 10 09:10:07.799 [INFO] my_cifar_run accumulated 2976 samples for epoch #26 from 2 peers. ETA 2.24 sec (refresh in 0.89 sec)
# Dec 10 09:10:08.923 [INFO] my_cifar_run accumulated 3712 samples for epoch #26 from 2 peers. ETA 1.11 sec (refresh in 0.50 sec)
# Dec 10 09:10:09.661 [INFO] my_cifar_run accumulated 4160 samples for epoch #26 from 2 peers. ETA 0.41 sec (refresh in 0.50 sec)
# Dec 10 09:10:10.073 [INFO] Transitioning to epoch 27
# Dec 10 09:10:10.148 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:10.361 [INFO] my_cifar_run accumulated 32 samples for epoch #27 from 2 peers. ETA 7.42 sec (refresh in 2.97 sec)
# Dec 10 09:10:12.486 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:12.490 [INFO] Received parameters from background averaging round
# Dec 10 09:10:13.542 [INFO] my_cifar_run accumulated 640 samples for epoch #27 from 2 peers. ETA 7.78 sec (refresh in 3.11 sec)
# Dec 10 09:10:16.890 [INFO] my_cifar_run accumulated 2464 samples for epoch #27 from 2 peers. ETA 3.60 sec (refresh in 1.44 sec)
# Dec 10 09:10:18.550 [INFO] my_cifar_run accumulated 3296 samples for epoch #27 from 2 peers. ETA 1.75 sec (refresh in 0.70 sec)
# Dec 10 09:10:19.458 [INFO] my_cifar_run accumulated 3744 samples for epoch #27 from 2 peers. ETA 0.90 sec (refresh in 0.50 sec)
# Dec 10 09:10:20.207 [INFO] my_cifar_run accumulated 4096 samples for epoch #27 from 2 peers. ETA 0.18 sec (refresh in 0.50 sec)
# Dec 10 09:10:20.458 [INFO] Transitioning to epoch 28
# Dec 10 09:10:20.566 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:20.907 [INFO] my_cifar_run accumulated 32 samples for epoch #28 from 2 peers. ETA 8.62 sec (refresh in 3.45 sec)
# Dec 10 09:10:22.097 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:22.101 [INFO] Received parameters from background averaging round
# Dec 10 09:10:24.569 [INFO] my_cifar_run accumulated 1568 samples for epoch #28 from 2 peers. ETA 4.52 sec (refresh in 1.81 sec)
# Dec 10 09:10:26.584 [INFO] my_cifar_run accumulated 2912 samples for epoch #28 from 2 peers. ETA 2.55 sec (refresh in 1.02 sec)
# Dec 10 09:10:27.827 [INFO] my_cifar_run accumulated 3744 samples for epoch #28 from 2 peers. ETA 1.32 sec (refresh in 0.53 sec)
# Dec 10 09:10:28.568 [INFO] my_cifar_run accumulated 4256 samples for epoch #28 from 2 peers. ETA 0.60 sec (refresh in 0.50 sec)
# Dec 10 09:10:29.273 [INFO] my_cifar_run accumulated 4736 samples for epoch #28 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:10:29.276 [INFO] Transitioning to epoch 29
# Dec 10 09:10:29.338 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:29.967 [INFO] my_cifar_run accumulated 32 samples for epoch #29 from 2 peers. ETA 7.00 sec (refresh in 2.80 sec)
# Dec 10 09:10:31.891 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:31.894 [INFO] Received parameters from background averaging round
# Dec 10 09:10:32.964 [INFO] my_cifar_run accumulated 480 samples for epoch #29 from 2 peers. ETA 8.89 sec (refresh in 3.56 sec)
# Dec 10 09:10:36.715 [INFO] my_cifar_run accumulated 2528 samples for epoch #29 from 2 peers. ETA 2.64 sec (refresh in 1.06 sec)
# Dec 10 09:10:37.976 [INFO] my_cifar_run accumulated 3360 samples for epoch #29 from 2 peers. ETA 1.41 sec (refresh in 0.56 sec)
# Dec 10 09:10:38.746 [INFO] my_cifar_run accumulated 3872 samples for epoch #29 from 2 peers. ETA 0.66 sec (refresh in 0.50 sec)
# Dec 10 09:10:39.441 [INFO] my_cifar_run accumulated 4320 samples for epoch #29 from 2 peers. ETA 0.01 sec (refresh in 0.50 sec)
# Dec 10 09:10:39.450 [INFO] Transitioning to epoch 30
# Dec 10 09:10:39.498 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:40.136 [INFO] my_cifar_run accumulated 32 samples for epoch #30 from 2 peers. ETA 7.02 sec (refresh in 2.81 sec)
# Dec 10 09:10:41.703 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:41.710 [INFO] Received parameters from background averaging round
# Dec 10 09:10:43.180 [INFO] my_cifar_run accumulated 928 samples for epoch #30 from 2 peers. ETA 6.44 sec (refresh in 2.57 sec)
# Dec 10 09:10:45.970 [INFO] my_cifar_run accumulated 2688 samples for epoch #30 from 2 peers. ETA 3.29 sec (refresh in 1.32 sec)
# Dec 10 09:10:47.492 [INFO] my_cifar_run accumulated 3456 samples for epoch #30 from 2 peers. ETA 1.95 sec (refresh in 0.78 sec)
# Dec 10 09:10:48.493 [INFO] my_cifar_run accumulated 3936 samples for epoch #30 from 2 peers. ETA 0.95 sec (refresh in 0.50 sec)
# Dec 10 09:10:49.252 [INFO] my_cifar_run accumulated 4288 samples for epoch #30 from 2 peers. ETA 0.20 sec (refresh in 0.50 sec)
# Dec 10 09:10:49.468 [INFO] Transitioning to epoch 31
# Dec 10 09:10:49.547 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:49.965 [INFO] my_cifar_run accumulated 32 samples for epoch #31 from 2 peers. ETA 8.26 sec (refresh in 3.30 sec)
# Dec 10 09:10:51.364 [INFO] Averaged parameters with 2 peers
# Dec 10 09:10:51.372 [INFO] Received parameters from background averaging round
# Dec 10 09:10:53.488 [INFO] my_cifar_run accumulated 1344 samples for epoch #31 from 2 peers. ETA 5.48 sec (refresh in 2.19 sec)
# Dec 10 09:10:55.890 [INFO] my_cifar_run accumulated 2944 samples for epoch #31 from 2 peers. ETA 2.76 sec (refresh in 1.10 sec)
# Dec 10 09:10:57.226 [INFO] my_cifar_run accumulated 3808 samples for epoch #31 from 2 peers. ETA 1.44 sec (refresh in 0.58 sec)
# Dec 10 09:10:58.016 [INFO] my_cifar_run accumulated 4352 samples for epoch #31 from 2 peers. ETA 0.66 sec (refresh in 0.50 sec)
# Dec 10 09:10:58.729 [INFO] my_cifar_run accumulated 4832 samples for epoch #31 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:10:58.734 [INFO] Transitioning to epoch 32
# Dec 10 09:10:58.797 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:10:59.423 [INFO] my_cifar_run accumulated 32 samples for epoch #32 from 2 peers. ETA 6.87 sec (refresh in 2.75 sec)
# Dec 10 09:11:01.241 [INFO] Averaged parameters with 2 peers
# Dec 10 09:11:01.245 [INFO] Received parameters from background averaging round
# Dec 10 09:11:02.387 [INFO] my_cifar_run accumulated 480 samples for epoch #32 from 2 peers. ETA 9.31 sec (refresh in 3.72 sec)
# Dec 10 09:11:06.379 [INFO] my_cifar_run accumulated 2496 samples for epoch #32 from 2 peers. ETA 3.00 sec (refresh in 1.20 sec)
# Dec 10 09:11:07.793 [INFO] my_cifar_run accumulated 3456 samples for epoch #32 from 2 peers. ETA 1.37 sec (refresh in 0.55 sec)
# Dec 10 09:11:08.583 [INFO] my_cifar_run accumulated 3936 samples for epoch #32 from 2 peers. ETA 0.64 sec (refresh in 0.50 sec)
# Dec 10 09:11:09.282 [INFO] my_cifar_run accumulated 4416 samples for epoch #32 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:11:09.286 [INFO] Transitioning to epoch 33
# Dec 10 09:11:09.352 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:11:09.975 [INFO] my_cifar_run accumulated 32 samples for epoch #33 from 2 peers. ETA 7.29 sec (refresh in 2.92 sec)
# Dec 10 09:11:10.898 [INFO] Averaged parameters with 2 peers
# Dec 10 09:11:10.900 [INFO] Received parameters from background averaging round

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from tqdm.auto import tqdm

import hivemind

# Create dataset and model, same as in the basic tutorial
# For this basic tutorial, we download only the training set
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)

model = nn.Sequential(nn.Conv2d(3, 16, (5, 5)), nn.MaxPool2d(2, 2), nn.ReLU(),
                      nn.Conv2d(16, 32, (5, 5)), nn.MaxPool2d(2, 2), nn.ReLU(),
                      nn.Flatten(), nn.Linear(32 * 5 * 5, 10))
opt = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Create DHT: a decentralized key-value storage shared between peers

# dht = hivemind.DHT(start=True)

# dht = hivemind.DHT(
#     # host_maddrs=["/ip4/0.0.0.0/tcp/0", "/ip4/0.0.0.0/udp/0/quic"],
#     initial_peers=[
#         f"/ip4/{ip_address}/tcp/16497/p2p/12D3KooWBCdJnh6r7n4L4zxCd3iEofpNDbJKLXQ5gq1DqK6RYbcH",
#     ], start=True)

dht = hivemind.DHT(
    # host_maddrs=["/ip4/0.0.0.0/tcp/0", "/ip4/0.0.0.0/udp/0/quic"],
    initial_peers=[
        f"/ip4/35.76.159.227/tcp/15048/p2p/12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW",
    ], start=True)

# dht = hivemind.DHT(initial_peers=['/ip4/172.28.0.12/tcp/40987/p2p/12D3KooWPJGzNpLzZqoALePdwVaXsoSC4KK1dAmupZ3H7WcvbHJ9'], start=True)


print("To join the training, use initial_peers =", [str(addr) for addr in dht.get_visible_maddrs()])

# Set up a decentralized optimizer that will average with peers in background
opt = hivemind.Optimizer(
    dht=dht,                  # use a DHT that is connected with other peers
    run_id='my_cifar_run',    # unique identifier of this collaborative run
    batch_size_per_step=32,   # each call to opt.step adds this many samples towards the next epoch
    target_batch_size=10000,  # after peers collectively process this many samples, average weights and begin the next epoch
    optimizer=opt,            # wrap the SGD optimizer defined above
    use_local_updates=True,   # perform optimizer steps with local gradients, average parameters in background
    matchmaking_time=3.0,     # when averaging parameters, gather peers in background for up to this many seconds
    averaging_timeout=10.0,   # give up on averaging if not successful in this many seconds
    verbose=True              # print logs incessently
)

# Note: if you intend to use GPU, switch to it only after the decentralized optimizer is created
with tqdm() as progressbar:
    while True:
        for x_batch, y_batch in torch.utils.data.DataLoader(trainset, shuffle=True, batch_size=32):
            opt.zero_grad()
            loss = F.cross_entropy(model(x_batch), y_batch)
            loss.backward()
            opt.step()

            progressbar.desc = f"loss = {loss.item():.3f}"
            progressbar.update()


# num_epochs = 1  # 设置你想要的 epoch 数
# for epoch in range(num_epochs):
#     with tqdm(total=len(trainset), desc=f"Epoch {epoch+1}/{num_epochs}") as progressbar:
#         for x_batch, y_batch in torch.utils.data.DataLoader(trainset, shuffle=True, batch_size=32):
#             opt.zero_grad()
#             loss = F.cross_entropy(model(x_batch), y_batch)
#             loss.backward()
#             opt.step()

#             progressbar.set_postfix(loss=loss.item())
#             progressbar.update(len(x_batch))
# Out:
# Files already downloaded and verified
# Dec 10 09:12:19.515 [INFO] Sending goodbye to peers...
# Dec 10 09:12:19.536 [INFO] No longer reporting progress for my_cifar_run
# Dec 10 09:12:19.546 [INFO] No longer fetching my_cifar_run_progress
# Dec 10 09:12:19.550 [INFO] Shutting down averagers...
# Dec 10 09:12:19.592 [INFO] Optimizer is shut down
# To join the training, use initial_peers = ['/ip4/127.0.0.1/tcp/39659/p2p/12D3KooWJKCoHE6EmXWRgGQfJyV5DF9GrAevjzkLwsnt8X2KW3x7']
# Dec 10 09:12:21.609 [INFO] my_cifar_run accumulated 32 samples for epoch #36 from 1 peers. ETA 12.74 sec (refresh in 3.19 sec)
# Dec 10 09:12:21.617 [INFO] Initializing optimizer manually since it has no tensors in state dict. To override this, provide initialize_optimizer=False
# Dec 10 09:12:21.673 [WARN] [hivemind.averaging.matchmaking.__init__:54] It is recommended to use request_timeout smaller than min_matchmaking_time. Otherwise, matchmaking can cause deadlocks in some rare cases. Please see Matchmaking docstring.
# 0it [00:00, ?it/s]
# Dec 10 09:12:21.929 [INFO] Peer is out of sync
# Dec 10 09:12:22.134 [INFO] Downloading parameters from peer 12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW
# Dec 10 09:12:22.783 [INFO] Finished downloading state from 12D3KooWE851VaSCr8NTw1ZkSKdpp1Xu5Ke6rxf3CmwzNwu7z3WW
# Dec 10 09:12:24.999 [INFO] my_cifar_run accumulated 1568 samples for epoch #36 from 2 peers. ETA 2.64 sec (refresh in 1.05 sec)
# Dec 10 09:12:26.263 [INFO] my_cifar_run accumulated 2464 samples for epoch #36 from 2 peers. ETA 1.52 sec (refresh in 0.61 sec)
# Dec 10 09:12:27.100 [INFO] my_cifar_run accumulated 3328 samples for epoch #36 from 2 peers. ETA 8.22 sec (refresh in 3.29 sec)
# Dec 10 09:12:30.608 [INFO] my_cifar_run accumulated 7488 samples for epoch #36 from 2 peers. ETA 1.84 sec (refresh in 0.73 sec)
# Dec 10 09:12:31.582 [INFO] my_cifar_run accumulated 8672 samples for epoch #36 from 2 peers. ETA 0.79 sec (refresh in 0.50 sec)
# Dec 10 09:12:32.290 [INFO] my_cifar_run accumulated 9504 samples for epoch #36 from 2 peers. ETA 0.13 sec (refresh in 0.50 sec)
# Dec 10 09:12:32.461 [INFO] Transitioning to epoch 37
# Dec 10 09:12:32.532 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:12:32.987 [INFO] my_cifar_run accumulated 64 samples for epoch #37 from 2 peers. ETA 7.79 sec (refresh in 3.12 sec)
# Dec 10 09:12:36.290 [INFO] Averaged parameters with 2 peers
# Dec 10 09:12:36.299 [INFO] Received parameters from background averaging round
# Dec 10 09:12:36.329 [INFO] my_cifar_run accumulated 64 samples for epoch #37 from 2 peers. ETA 4.45 sec (refresh in 1.78 sec)
# Dec 10 09:12:38.412 [INFO] my_cifar_run accumulated 2784 samples for epoch #37 from 2 peers. ETA 4.98 sec (refresh in 1.99 sec)
# Dec 10 09:12:40.676 [INFO] my_cifar_run accumulated 6048 samples for epoch #37 from 2 peers. ETA 2.53 sec (refresh in 1.01 sec)
# Dec 10 09:12:41.899 [INFO] my_cifar_run accumulated 7840 samples for epoch #37 from 2 peers. ETA 1.23 sec (refresh in 0.50 sec)
# Dec 10 09:12:42.641 [INFO] my_cifar_run accumulated 8768 samples for epoch #37 from 2 peers. ETA 0.59 sec (refresh in 0.50 sec)
# Dec 10 09:12:43.340 [INFO] my_cifar_run accumulated 9632 samples for epoch #37 from 2 peers. ETA 0.03 sec (refresh in 0.50 sec)
# Dec 10 09:12:43.342 [INFO] Transitioning to epoch 38
# Dec 10 09:12:43.406 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:12:44.035 [INFO] my_cifar_run accumulated 64 samples for epoch #38 from 2 peers. ETA 8.07 sec (refresh in 3.23 sec)
# Dec 10 09:12:46.966 [INFO] Averaged parameters with 2 peers
# Dec 10 09:12:46.972 [INFO] Received parameters from background averaging round
# Dec 10 09:12:47.505 [INFO] my_cifar_run accumulated 160 samples for epoch #38 from 2 peers. ETA 13.19 sec (refresh in 5.28 sec)
# Dec 10 09:12:53.051 [INFO] my_cifar_run accumulated 7776 samples for epoch #38 from 2 peers. ETA 1.13 sec (refresh in 0.50 sec)
# Dec 10 09:12:53.776 [INFO] my_cifar_run accumulated 8992 samples for epoch #38 from 2 peers. ETA 0.32 sec (refresh in 0.50 sec)
# Dec 10 09:12:54.139 [INFO] Transitioning to epoch 39
# Dec 10 09:12:54.212 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:12:54.489 [INFO] my_cifar_run accumulated 32 samples for epoch #39 from 2 peers. ETA 6.74 sec (refresh in 2.70 sec)
# Dec 10 09:12:57.687 [INFO] my_cifar_run accumulated 32 samples for epoch #39 from 2 peers. ETA 8.31 sec (refresh in 3.32 sec)
# Dec 10 09:13:00.920 [INFO] Averaged parameters with 2 peers
# Dec 10 09:13:00.924 [INFO] Received parameters from background averaging round
# Dec 10 09:13:01.228 [INFO] my_cifar_run accumulated 64 samples for epoch #39 from 2 peers. ETA 7.21 sec (refresh in 2.88 sec)
# Dec 10 09:13:04.321 [INFO] my_cifar_run accumulated 2848 samples for epoch #39 from 2 peers. ETA 6.85 sec (refresh in 2.74 sec)
# Dec 10 09:13:07.363 [INFO] my_cifar_run accumulated 6688 samples for epoch #39 from 2 peers. ETA 1.70 sec (refresh in 0.68 sec)
# Dec 10 09:13:08.265 [INFO] my_cifar_run accumulated 8416 samples for epoch #39 from 2 peers. ETA 0.76 sec (refresh in 0.50 sec)
# Dec 10 09:13:08.978 [INFO] my_cifar_run accumulated 9440 samples for epoch #39 from 2 peers. ETA 0.10 sec (refresh in 0.50 sec)
# Dec 10 09:13:09.121 [INFO] Transitioning to epoch 40
# Dec 10 09:13:09.187 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:13:09.672 [INFO] my_cifar_run accumulated 32 samples for epoch #40 from 2 peers. ETA 6.77 sec (refresh in 2.71 sec)
# Dec 10 09:13:12.577 [INFO] my_cifar_run accumulated 32 samples for epoch #40 from 2 peers. ETA 5.49 sec (refresh in 2.19 sec)
# Dec 10 09:13:14.966 [INFO] my_cifar_run accumulated 64 samples for epoch #40 from 2 peers. ETA 3.05 sec (refresh in 1.22 sec)
# Dec 10 09:13:15.723 [INFO] Averaged parameters with 2 peers
# Dec 10 09:13:15.727 [INFO] Received parameters from background averaging round
# Dec 10 09:13:16.434 [INFO] my_cifar_run accumulated 352 samples for epoch #40 from 2 peers. ETA 55.83 sec (refresh in 10.00 sec)
# Dec 10 09:13:26.681 [INFO] my_cifar_run accumulated 14208 samples for epoch #40 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:13:26.741 [INFO] Transitioning to epoch 41
# Dec 10 09:13:26.897 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:13:27.375 [INFO] my_cifar_run accumulated 64 samples for epoch #41 from 2 peers. ETA 7.54 sec (refresh in 3.02 sec)
# Dec 10 09:13:30.321 [INFO] Averaged parameters with 2 peers
# Dec 10 09:13:30.324 [INFO] Received parameters from background averaging round
# Dec 10 09:13:30.600 [INFO] my_cifar_run accumulated 96 samples for epoch #41 from 2 peers. ETA 8.17 sec (refresh in 3.27 sec)
# Dec 10 09:13:34.109 [INFO] my_cifar_run accumulated 4096 samples for epoch #41 from 2 peers. ETA 4.90 sec (refresh in 1.96 sec)
# Dec 10 09:13:36.281 [INFO] my_cifar_run accumulated 6880 samples for epoch #41 from 2 peers. ETA 1.78 sec (refresh in 0.71 sec)
# Dec 10 09:13:37.197 [INFO] my_cifar_run accumulated 8192 samples for epoch #41 from 2 peers. ETA 1.03 sec (refresh in 0.50 sec)
# Dec 10 09:13:37.923 [INFO] my_cifar_run accumulated 9216 samples for epoch #41 from 2 peers. ETA 0.26 sec (refresh in 0.50 sec)
# Dec 10 09:13:38.197 [INFO] Transitioning to epoch 42
# Dec 10 09:13:38.278 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:13:38.616 [INFO] my_cifar_run accumulated 32 samples for epoch #42 from 2 peers. ETA 7.48 sec (refresh in 2.99 sec)
# Dec 10 09:13:41.793 [INFO] Averaged parameters with 2 peers
# Dec 10 09:13:41.796 [INFO] Received parameters from background averaging round
# Dec 10 09:13:41.851 [INFO] my_cifar_run accumulated 64 samples for epoch #42 from 2 peers. ETA 4.17 sec (refresh in 1.67 sec)
# Dec 10 09:13:43.741 [INFO] my_cifar_run accumulated 2464 samples for epoch #42 from 2 peers. ETA 5.75 sec (refresh in 2.30 sec)
# Dec 10 09:13:46.262 [INFO] my_cifar_run accumulated 5856 samples for epoch #42 from 2 peers. ETA 3.10 sec (refresh in 1.24 sec)
# Dec 10 09:13:47.749 [INFO] my_cifar_run accumulated 7328 samples for epoch #42 from 2 peers. ETA 2.49 sec (refresh in 1.00 sec)
# Dec 10 09:13:48.983 [INFO] my_cifar_run accumulated 8416 samples for epoch #42 from 2 peers. ETA 1.34 sec (refresh in 0.54 sec)
# Dec 10 09:13:49.727 [INFO] my_cifar_run accumulated 9152 samples for epoch #42 from 2 peers. ETA 0.59 sec (refresh in 0.50 sec)
# Dec 10 09:13:50.440 [INFO] my_cifar_run accumulated 9760 samples for epoch #42 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:13:50.442 [INFO] Transitioning to epoch 43
# Dec 10 09:13:50.521 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:13:51.183 [INFO] my_cifar_run accumulated 64 samples for epoch #43 from 2 peers. ETA 9.94 sec (refresh in 3.98 sec)
# Dec 10 09:13:54.076 [INFO] Averaged parameters with 2 peers
# Dec 10 09:13:54.083 [INFO] Received parameters from background averaging round
# Dec 10 09:13:55.391 [INFO] my_cifar_run accumulated 1184 samples for epoch #43 from 2 peers. ETA 14.41 sec (refresh in 5.77 sec)
# Dec 10 09:14:01.385 [INFO] my_cifar_run accumulated 8832 samples for epoch #43 from 2 peers. ETA 0.57 sec (refresh in 0.50 sec)
# Dec 10 09:14:02.089 [INFO] my_cifar_run accumulated 9728 samples for epoch #43 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:14:02.091 [INFO] Transitioning to epoch 44
# Dec 10 09:14:02.158 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:14:02.783 [INFO] my_cifar_run accumulated 64 samples for epoch #44 from 2 peers. ETA 7.93 sec (refresh in 3.17 sec)
# Dec 10 09:14:05.712 [INFO] Averaged parameters with 2 peers
# Dec 10 09:14:05.715 [INFO] Received parameters from background averaging round
# Dec 10 09:14:06.164 [INFO] my_cifar_run accumulated 224 samples for epoch #44 from 2 peers. ETA 12.12 sec (refresh in 4.85 sec)
# Dec 10 09:14:11.291 [INFO] my_cifar_run accumulated 6784 samples for epoch #44 from 2 peers. ETA 2.16 sec (refresh in 0.86 sec)
# Dec 10 09:14:12.377 [INFO] my_cifar_run accumulated 8128 samples for epoch #44 from 2 peers. ETA 1.36 sec (refresh in 0.55 sec)
# Dec 10 09:14:13.137 [INFO] my_cifar_run accumulated 8992 samples for epoch #44 from 2 peers. ETA 0.52 sec (refresh in 0.50 sec)
# Dec 10 09:14:13.836 [INFO] my_cifar_run accumulated 9824 samples for epoch #44 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:14:13.841 [INFO] Transitioning to epoch 45
# Dec 10 09:14:13.962 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:14:14.545 [INFO] my_cifar_run accumulated 32 samples for epoch #45 from 2 peers. ETA 9.00 sec (refresh in 3.60 sec)
# Dec 10 09:14:17.606 [INFO] Averaged parameters with 2 peers
# Dec 10 09:14:17.621 [INFO] Received parameters from background averaging round
# Dec 10 09:14:18.429 [INFO] my_cifar_run accumulated 640 samples for epoch #45 from 2 peers. ETA 21.01 sec (refresh in 8.40 sec)
# Dec 10 09:14:27.111 [INFO] my_cifar_run accumulated 32 samples for epoch #46 from 2 peers. ETA 6.48 sec (refresh in 2.59 sec)
# Dec 10 09:14:27.167 [INFO] Transitioning to epoch 46
# Dec 10 09:14:27.284 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:14:28.252 [INFO] Averaged parameters with 2 peers
# Dec 10 09:14:28.255 [INFO] Received parameters from background averaging round
# Dec 10 09:14:29.940 [INFO] my_cifar_run accumulated 1696 samples for epoch #46 from 2 peers. ETA 8.72 sec (refresh in 3.49 sec)
# Dec 10 09:14:33.674 [INFO] my_cifar_run accumulated 6144 samples for epoch #46 from 2 peers. ETA 2.89 sec (refresh in 1.16 sec)
# Dec 10 09:14:35.182 [INFO] my_cifar_run accumulated 7968 samples for epoch #46 from 2 peers. ETA 0.83 sec (refresh in 0.50 sec)
# Dec 10 09:14:35.946 [INFO] my_cifar_run accumulated 9408 samples for epoch #46 from 2 peers. ETA 0.10 sec (refresh in 0.50 sec)
# Dec 10 09:14:36.061 [INFO] Transitioning to epoch 47
# Dec 10 09:14:36.140 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:14:36.639 [INFO] my_cifar_run accumulated 64 samples for epoch #47 from 2 peers. ETA 6.68 sec (refresh in 2.67 sec)
# Dec 10 09:14:39.505 [INFO] my_cifar_run accumulated 64 samples for epoch #47 from 2 peers. ETA 3.81 sec (refresh in 1.52 sec)
# Dec 10 09:14:39.803 [INFO] Averaged parameters with 2 peers
# Dec 10 09:14:39.814 [INFO] Received parameters from background averaging round
# Dec 10 09:14:41.293 [INFO] my_cifar_run accumulated 1504 samples for epoch #47 from 2 peers. ETA 10.58 sec (refresh in 4.23 sec)
# Dec 10 09:14:45.761 [INFO] my_cifar_run accumulated 6784 samples for epoch #47 from 2 peers. ETA 2.43 sec (refresh in 0.97 sec)
# Dec 10 09:14:46.953 [INFO] my_cifar_run accumulated 8192 samples for epoch #47 from 2 peers. ETA 1.25 sec (refresh in 0.50 sec)
# Dec 10 09:14:47.660 [INFO] my_cifar_run accumulated 9024 samples for epoch #47 from 2 peers. ETA 0.49 sec (refresh in 0.50 sec)
# Dec 10 09:14:48.363 [INFO] my_cifar_run accumulated 9856 samples for epoch #47 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:14:48.365 [INFO] Transitioning to epoch 48
# Dec 10 09:14:48.420 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:14:49.062 [INFO] my_cifar_run accumulated 64 samples for epoch #48 from 2 peers. ETA 8.14 sec (refresh in 3.25 sec)
# Dec 10 09:14:51.993 [INFO] Averaged parameters with 2 peers
# Dec 10 09:14:51.997 [INFO] Received parameters from background averaging round
# Dec 10 09:14:52.652 [INFO] my_cifar_run accumulated 512 samples for epoch #48 from 2 peers. ETA 34.10 sec (refresh in 10.00 sec)
# Dec 10 09:15:02.885 [INFO] my_cifar_run accumulated 32 samples for epoch #49 from 2 peers. ETA 5.90 sec (refresh in 2.36 sec)
# Dec 10 09:15:02.908 [INFO] Transitioning to epoch 49
# Dec 10 09:15:02.966 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:15:05.444 [INFO] my_cifar_run accumulated 64 samples for epoch #49 from 2 peers. ETA 3.77 sec (refresh in 1.51 sec)
# Dec 10 09:15:06.565 [INFO] Averaged parameters with 2 peers
# Dec 10 09:15:06.574 [INFO] Received parameters from background averaging round
# Dec 10 09:15:07.287 [INFO] my_cifar_run accumulated 544 samples for epoch #49 from 2 peers. ETA 40.35 sec (refresh in 10.00 sec)
# Dec 10 09:15:17.485 [INFO] my_cifar_run accumulated 32 samples for epoch #50 from 2 peers. ETA 6.86 sec (refresh in 2.75 sec)
# Dec 10 09:15:17.494 [INFO] Transitioning to epoch 50
# Dec 10 09:15:17.564 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:15:20.448 [INFO] my_cifar_run accumulated 64 samples for epoch #50 from 2 peers. ETA 4.05 sec (refresh in 1.62 sec)
# Dec 10 09:15:21.120 [INFO] Averaged parameters with 2 peers
# Dec 10 09:15:21.127 [INFO] Received parameters from background averaging round
# Dec 10 09:15:22.267 [INFO] my_cifar_run accumulated 1312 samples for epoch #50 from 2 peers. ETA 15.31 sec (refresh in 6.12 sec)
# Dec 10 09:15:28.656 [INFO] my_cifar_run accumulated 9440 samples for epoch #50 from 2 peers. ETA 0.24 sec (refresh in 0.50 sec)
# Dec 10 09:15:28.936 [INFO] Transitioning to epoch 51
# Dec 10 09:15:29.048 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:15:29.384 [INFO] my_cifar_run accumulated 32 samples for epoch #51 from 2 peers. ETA 10.17 sec (refresh in 4.07 sec)
# Dec 10 09:15:33.644 [INFO] my_cifar_run accumulated 64 samples for epoch #51 from 2 peers. ETA 6.48 sec (refresh in 2.59 sec)
# Dec 10 09:15:35.601 [INFO] Averaged parameters with 2 peers
# Dec 10 09:15:35.607 [INFO] Received parameters from background averaging round
# Dec 10 09:15:36.453 [INFO] my_cifar_run accumulated 896 samples for epoch #51 from 2 peers. ETA 25.42 sec (refresh in 10.00 sec)
# Dec 10 09:15:46.667 [INFO] my_cifar_run accumulated 32 samples for epoch #52 from 2 peers. ETA 8.00 sec (refresh in 3.20 sec)
# Dec 10 09:15:46.706 [INFO] Transitioning to epoch 52
# Dec 10 09:15:46.779 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:15:49.955 [INFO] Averaged parameters with 2 peers
# Dec 10 09:15:49.963 [INFO] Received parameters from background averaging round
# Dec 10 09:15:50.070 [INFO] my_cifar_run accumulated 64 samples for epoch #52 from 2 peers. ETA 4.53 sec (refresh in 1.81 sec)
# Dec 10 09:15:52.098 [INFO] my_cifar_run accumulated 2976 samples for epoch #52 from 2 peers. ETA 4.89 sec (refresh in 1.95 sec)
# Dec 10 09:15:54.261 [INFO] my_cifar_run accumulated 6144 samples for epoch #52 from 2 peers. ETA 2.41 sec (refresh in 0.96 sec)
# Dec 10 09:15:55.437 [INFO] my_cifar_run accumulated 7872 samples for epoch #52 from 2 peers. ETA 1.10 sec (refresh in 0.50 sec)
# Dec 10 09:15:56.148 [INFO] my_cifar_run accumulated 8736 samples for epoch #52 from 2 peers. ETA 0.73 sec (refresh in 0.50 sec)
# Dec 10 09:15:56.922 [INFO] my_cifar_run accumulated 9664 samples for epoch #52 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:15:56.945 [INFO] Transitioning to epoch 53
# Dec 10 09:15:57.037 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:15:57.642 [INFO] my_cifar_run accumulated 32 samples for epoch #53 from 2 peers. ETA 8.01 sec (refresh in 3.20 sec)
# Dec 10 09:16:01.040 [INFO] my_cifar_run accumulated 64 samples for epoch #53 from 2 peers. ETA 6.17 sec (refresh in 2.47 sec)
# Dec 10 09:16:03.345 [INFO] Averaged parameters with 2 peers
# Dec 10 09:16:03.355 [INFO] Received parameters from background averaging round
# Dec 10 09:16:03.716 [INFO] my_cifar_run accumulated 288 samples for epoch #53 from 2 peers. ETA 60.00 sec (refresh in 10.00 sec)
# Dec 10 09:16:13.993 [INFO] my_cifar_run accumulated 32 samples for epoch #54 from 2 peers. ETA 5.54 sec (refresh in 2.22 sec)
# Dec 10 09:16:14.030 [INFO] Transitioning to epoch 54
# Dec 10 09:16:14.097 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:16:16.404 [INFO] my_cifar_run accumulated 64 samples for epoch #54 from 2 peers. ETA 3.25 sec (refresh in 1.30 sec)
# Dec 10 09:16:16.852 [INFO] Averaged parameters with 2 peers
# Dec 10 09:16:16.859 [INFO] Received parameters from background averaging round
# Dec 10 09:16:17.954 [INFO] my_cifar_run accumulated 1280 samples for epoch #54 from 2 peers. ETA 15.01 sec (refresh in 6.00 sec)
# Dec 10 09:16:24.161 [INFO] my_cifar_run accumulated 32 samples for epoch #55 from 2 peers. ETA 7.96 sec (refresh in 3.18 sec)
# Dec 10 09:16:24.180 [INFO] Transitioning to epoch 55
# Dec 10 09:16:24.226 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:16:27.525 [INFO] Averaged parameters with 2 peers
# Dec 10 09:16:27.531 [INFO] Received parameters from background averaging round
# Dec 10 09:16:27.666 [INFO] my_cifar_run accumulated 64 samples for epoch #55 from 2 peers. ETA 4.26 sec (refresh in 1.70 sec)
# Dec 10 09:16:29.590 [INFO] my_cifar_run accumulated 2752 samples for epoch #55 from 2 peers. ETA 5.26 sec (refresh in 2.10 sec)
# Dec 10 09:16:31.918 [INFO] my_cifar_run accumulated 6016 samples for epoch #55 from 2 peers. ETA 2.49 sec (refresh in 1.00 sec)
# Dec 10 09:16:33.163 [INFO] my_cifar_run accumulated 7744 samples for epoch #55 from 2 peers. ETA 1.21 sec (refresh in 0.50 sec)
# Dec 10 09:16:33.970 [INFO] my_cifar_run accumulated 8768 samples for epoch #55 from 2 peers. ETA 0.45 sec (refresh in 0.50 sec)
# Dec 10 09:16:34.430 [INFO] Transitioning to epoch 56
# Dec 10 09:16:34.502 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:16:34.804 [INFO] my_cifar_run accumulated 0 samples for epoch #56 from 2 peers. ETA 6.17 sec (refresh in 2.47 sec)
# Dec 10 09:16:37.469 [INFO] my_cifar_run accumulated 64 samples for epoch #56 from 2 peers. ETA 3.91 sec (refresh in 1.56 sec)
# Dec 10 09:16:38.050 [INFO] Averaged parameters with 2 peers
# Dec 10 09:16:38.053 [INFO] Received parameters from background averaging round
# Dec 10 09:16:39.275 [INFO] my_cifar_run accumulated 864 samples for epoch #56 from 2 peers. ETA 23.40 sec (refresh in 9.36 sec)
# Dec 10 09:16:48.863 [INFO] my_cifar_run accumulated 32 samples for epoch #57 from 2 peers. ETA 5.60 sec (refresh in 2.24 sec)
# Dec 10 09:16:48.923 [INFO] Transitioning to epoch 57
# Dec 10 09:16:48.988 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:16:50.513 [INFO] Averaged parameters with 2 peers
# Dec 10 09:16:50.515 [INFO] Received parameters from background averaging round
# Dec 10 09:16:51.331 [INFO] my_cifar_run accumulated 768 samples for epoch #57 from 2 peers. ETA 17.92 sec (refresh in 7.17 sec)
# Dec 10 09:16:58.756 [INFO] my_cifar_run accumulated 8960 samples for epoch #57 from 2 peers. ETA 0.57 sec (refresh in 0.50 sec)
# Dec 10 09:16:59.486 [INFO] my_cifar_run accumulated 9888 samples for epoch #57 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:16:59.494 [INFO] Transitioning to epoch 58
# Dec 10 09:16:59.563 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:17:00.183 [INFO] my_cifar_run accumulated 64 samples for epoch #58 from 2 peers. ETA 7.08 sec (refresh in 2.83 sec)
# Dec 10 09:17:03.186 [INFO] Averaged parameters with 2 peers
# Dec 10 09:17:03.193 [INFO] Received parameters from background averaging round
# Dec 10 09:17:03.296 [INFO] my_cifar_run accumulated 64 samples for epoch #58 from 2 peers. ETA 3.97 sec (refresh in 1.59 sec)
# Dec 10 09:17:05.101 [INFO] my_cifar_run accumulated 2656 samples for epoch #58 from 2 peers. ETA 5.46 sec (refresh in 2.18 sec)
# Dec 10 09:17:07.514 [INFO] my_cifar_run accumulated 5536 samples for epoch #58 from 2 peers. ETA 3.18 sec (refresh in 1.27 sec)
# Dec 10 09:17:08.986 [INFO] my_cifar_run accumulated 7296 samples for epoch #58 from 2 peers. ETA 2.07 sec (refresh in 0.83 sec)
# Dec 10 09:17:10.251 [INFO] my_cifar_run accumulated 8352 samples for epoch #58 from 2 peers. ETA 1.39 sec (refresh in 0.56 sec)
# Dec 10 09:17:11.037 [INFO] my_cifar_run accumulated 9312 samples for epoch #58 from 2 peers. ETA 0.28 sec (refresh in 0.50 sec)
# Dec 10 09:17:11.349 [INFO] Transitioning to epoch 59
# Dec 10 09:17:11.507 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:17:11.736 [INFO] my_cifar_run accumulated 64 samples for epoch #59 from 2 peers. ETA 8.05 sec (refresh in 3.22 sec)
# Dec 10 09:17:15.025 [INFO] Averaged parameters with 2 peers
# Dec 10 09:17:15.034 [INFO] Received parameters from background averaging round
# Dec 10 09:17:15.151 [INFO] my_cifar_run accumulated 64 samples for epoch #59 from 2 peers. ETA 4.64 sec (refresh in 1.85 sec)
# Dec 10 09:17:17.299 [INFO] my_cifar_run accumulated 2880 samples for epoch #59 from 2 peers. ETA 5.12 sec (refresh in 2.05 sec)
# Dec 10 09:17:19.571 [INFO] my_cifar_run accumulated 6400 samples for epoch #59 from 2 peers. ETA 2.11 sec (refresh in 0.84 sec)
# Dec 10 09:17:20.612 [INFO] my_cifar_run accumulated 7936 samples for epoch #59 from 2 peers. ETA 1.09 sec (refresh in 0.50 sec)
# Dec 10 09:17:21.327 [INFO] my_cifar_run accumulated 8736 samples for epoch #59 from 2 peers. ETA 0.74 sec (refresh in 0.50 sec)
# Dec 10 09:17:22.043 [INFO] my_cifar_run accumulated 9600 samples for epoch #59 from 2 peers. ETA 0.04 sec (refresh in 0.50 sec)
# Dec 10 09:17:22.102 [INFO] Transitioning to epoch 60
# Dec 10 09:17:22.171 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:17:22.746 [INFO] my_cifar_run accumulated 64 samples for epoch #60 from 2 peers. ETA 8.74 sec (refresh in 3.50 sec)
# Dec 10 09:17:25.731 [INFO] Averaged parameters with 2 peers
# Dec 10 09:17:25.738 [INFO] Received parameters from background averaging round
# Dec 10 09:17:26.475 [INFO] my_cifar_run accumulated 480 samples for epoch #60 from 2 peers. ETA 35.12 sec (refresh in 10.00 sec)
# Dec 10 09:17:36.670 [INFO] my_cifar_run accumulated 32 samples for epoch #61 from 2 peers. ETA 9.90 sec (refresh in 3.96 sec)
# Dec 10 09:17:36.706 [INFO] Transitioning to epoch 61
# Dec 10 09:17:36.790 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:17:39.785 [INFO] Averaged parameters with 2 peers
# Dec 10 09:17:39.788 [INFO] Received parameters from background averaging round
# Dec 10 09:17:40.848 [INFO] my_cifar_run accumulated 1248 samples for epoch #61 from 2 peers. ETA 13.35 sec (refresh in 5.34 sec)
# Dec 10 09:17:46.470 [INFO] my_cifar_run accumulated 9216 samples for epoch #61 from 2 peers. ETA 0.14 sec (refresh in 0.50 sec)
# Dec 10 09:17:46.665 [INFO] Transitioning to epoch 62
# Dec 10 09:17:46.737 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:17:47.167 [INFO] my_cifar_run accumulated 32 samples for epoch #62 from 2 peers. ETA 6.53 sec (refresh in 2.61 sec)
# Dec 10 09:17:49.977 [INFO] my_cifar_run accumulated 64 samples for epoch #62 from 2 peers. ETA 5.93 sec (refresh in 2.37 sec)
# Dec 10 09:17:50.286 [INFO] Averaged parameters with 2 peers
# Dec 10 09:17:50.292 [INFO] Received parameters from background averaging round
# Dec 10 09:17:52.602 [INFO] my_cifar_run accumulated 2080 samples for epoch #62 from 2 peers. ETA 7.65 sec (refresh in 3.06 sec)
# Dec 10 09:17:55.903 [INFO] my_cifar_run accumulated 6688 samples for epoch #62 from 2 peers. ETA 2.06 sec (refresh in 0.82 sec)
# Dec 10 09:17:56.934 [INFO] my_cifar_run accumulated 8192 samples for epoch #62 from 2 peers. ETA 1.01 sec (refresh in 0.50 sec)
# Dec 10 09:17:57.693 [INFO] my_cifar_run accumulated 9280 samples for epoch #62 from 2 peers. ETA 0.17 sec (refresh in 0.50 sec)
# Dec 10 09:17:57.870 [INFO] Transitioning to epoch 63
# Dec 10 09:17:57.973 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:17:58.396 [INFO] my_cifar_run accumulated 32 samples for epoch #63 from 2 peers. ETA 7.00 sec (refresh in 2.80 sec)
# Dec 10 09:18:01.391 [INFO] my_cifar_run accumulated 64 samples for epoch #63 from 2 peers. ETA 4.82 sec (refresh in 1.93 sec)
# Dec 10 09:18:01.481 [INFO] Averaged parameters with 2 peers
# Dec 10 09:18:01.484 [INFO] Received parameters from background averaging round
# Dec 10 09:18:03.587 [INFO] my_cifar_run accumulated 2240 samples for epoch #63 from 2 peers. ETA 6.57 sec (refresh in 2.63 sec)
# Dec 10 09:18:06.442 [INFO] my_cifar_run accumulated 4864 samples for epoch #63 from 2 peers. ETA 5.37 sec (refresh in 2.15 sec)
# Dec 10 09:18:08.912 [INFO] my_cifar_run accumulated 7584 samples for epoch #63 from 2 peers. ETA 1.68 sec (refresh in 0.67 sec)
# Dec 10 09:18:09.810 [INFO] my_cifar_run accumulated 8800 samples for epoch #63 from 2 peers. ETA 0.63 sec (refresh in 0.50 sec)
# Dec 10 09:18:10.519 [INFO] my_cifar_run accumulated 9792 samples for epoch #63 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:18:10.522 [INFO] Transitioning to epoch 64
# Dec 10 09:18:10.600 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:18:11.216 [INFO] my_cifar_run accumulated 64 samples for epoch #64 from 2 peers. ETA 7.14 sec (refresh in 2.86 sec)
# Dec 10 09:18:14.132 [INFO] Averaged parameters with 2 peers
# Dec 10 09:18:14.140 [INFO] Received parameters from background averaging round
# Dec 10 09:18:14.266 [INFO] my_cifar_run accumulated 64 samples for epoch #64 from 2 peers. ETA 4.09 sec (refresh in 1.64 sec)
# Dec 10 09:18:16.117 [INFO] my_cifar_run accumulated 2496 samples for epoch #64 from 2 peers. ETA 5.61 sec (refresh in 2.24 sec)
# Dec 10 09:18:18.566 [INFO] my_cifar_run accumulated 5696 samples for epoch #64 from 2 peers. ETA 3.30 sec (refresh in 1.32 sec)
# Dec 10 09:18:20.130 [INFO] my_cifar_run accumulated 7456 samples for epoch #64 from 2 peers. ETA 1.75 sec (refresh in 0.70 sec)
# Dec 10 09:18:21.052 [INFO] my_cifar_run accumulated 8384 samples for epoch #64 from 2 peers. ETA 1.29 sec (refresh in 0.52 sec)
# Dec 10 09:18:21.798 [INFO] my_cifar_run accumulated 9024 samples for epoch #64 from 2 peers. ETA 0.69 sec (refresh in 0.50 sec)
# Dec 10 09:18:22.515 [INFO] my_cifar_run accumulated 9664 samples for epoch #64 from 2 peers. ETA 0.02 sec (refresh in 0.50 sec)
# Dec 10 09:18:22.625 [INFO] Transitioning to epoch 65
# Dec 10 09:18:22.740 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:18:23.223 [INFO] my_cifar_run accumulated 64 samples for epoch #65 from 2 peers. ETA 10.59 sec (refresh in 4.24 sec)
# Dec 10 09:18:26.224 [INFO] Averaged parameters with 2 peers
# Dec 10 09:18:26.227 [INFO] Received parameters from background averaging round
# Dec 10 09:18:27.698 [INFO] my_cifar_run accumulated 1888 samples for epoch #65 from 2 peers. ETA 7.76 sec (refresh in 3.10 sec)
# Dec 10 09:18:31.053 [INFO] my_cifar_run accumulated 6592 samples for epoch #65 from 2 peers. ETA 1.91 sec (refresh in 0.76 sec)
# Dec 10 09:18:32.034 [INFO] my_cifar_run accumulated 8192 samples for epoch #65 from 2 peers. ETA 1.00 sec (refresh in 0.50 sec)
# Dec 10 09:18:32.739 [INFO] my_cifar_run accumulated 9216 samples for epoch #65 from 2 peers. ETA 0.25 sec (refresh in 0.50 sec)
# Dec 10 09:18:33.033 [INFO] Transitioning to epoch 66
# Dec 10 09:18:33.113 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:18:33.437 [INFO] my_cifar_run accumulated 32 samples for epoch #66 from 2 peers. ETA 8.50 sec (refresh in 3.40 sec)
# Dec 10 09:18:36.639 [INFO] Averaged parameters with 2 peers
# Dec 10 09:18:36.643 [INFO] Received parameters from background averaging round
# Dec 10 09:18:37.064 [INFO] my_cifar_run accumulated 192 samples for epoch #66 from 2 peers. ETA 12.92 sec (refresh in 5.17 sec)
# Dec 10 09:18:42.437 [INFO] my_cifar_run accumulated 8096 samples for epoch #66 from 2 peers. ETA 0.98 sec (refresh in 0.50 sec)
# Dec 10 09:18:43.157 [INFO] my_cifar_run accumulated 9088 samples for epoch #66 from 2 peers. ETA 0.39 sec (refresh in 0.50 sec)
# Dec 10 09:18:43.598 [INFO] Transitioning to epoch 67
# Dec 10 09:18:43.661 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:18:43.892 [INFO] my_cifar_run accumulated 32 samples for epoch #67 from 2 peers. ETA 6.95 sec (refresh in 2.78 sec)
# Dec 10 09:18:46.867 [INFO] my_cifar_run accumulated 64 samples for epoch #67 from 2 peers. ETA 6.72 sec (refresh in 2.69 sec)
# Dec 10 09:18:49.751 [INFO] my_cifar_run accumulated 64 samples for epoch #67 from 2 peers. ETA 3.84 sec (refresh in 1.54 sec)
# Dec 10 09:18:50.075 [INFO] Averaged parameters with 2 peers
# Dec 10 09:18:50.086 [INFO] Received parameters from background averaging round
# Dec 10 09:18:51.507 [INFO] my_cifar_run accumulated 1824 samples for epoch #67 from 2 peers. ETA 9.12 sec (refresh in 3.65 sec)
# Dec 10 09:18:55.367 [INFO] my_cifar_run accumulated 7456 samples for epoch #67 from 2 peers. ETA 1.43 sec (refresh in 0.57 sec)
# Dec 10 09:18:56.152 [INFO] my_cifar_run accumulated 8576 samples for epoch #67 from 2 peers. ETA 0.71 sec (refresh in 0.50 sec)
# Dec 10 09:18:56.899 [INFO] my_cifar_run accumulated 9600 samples for epoch #67 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:18:56.958 [INFO] Transitioning to epoch 68
# Dec 10 09:18:57.051 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:18:57.592 [INFO] my_cifar_run accumulated 64 samples for epoch #68 from 2 peers. ETA 7.14 sec (refresh in 2.85 sec)
# Dec 10 09:19:00.602 [INFO] Averaged parameters with 2 peers
# Dec 10 09:19:00.610 [INFO] Received parameters from background averaging round
# Dec 10 09:19:00.669 [INFO] my_cifar_run accumulated 64 samples for epoch #68 from 2 peers. ETA 4.06 sec (refresh in 1.62 sec)
# Dec 10 09:19:02.504 [INFO] my_cifar_run accumulated 1600 samples for epoch #68 from 2 peers. ETA 12.98 sec (refresh in 5.19 sec)
# Dec 10 09:19:07.903 [INFO] my_cifar_run accumulated 8864 samples for epoch #68 from 2 peers. ETA 0.48 sec (refresh in 0.50 sec)
# Dec 10 09:19:08.615 [INFO] my_cifar_run accumulated 9888 samples for epoch #68 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:19:08.618 [INFO] Transitioning to epoch 69
# Dec 10 09:19:08.680 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:19:09.309 [INFO] my_cifar_run accumulated 64 samples for epoch #69 from 2 peers. ETA 6.31 sec (refresh in 2.52 sec)
# Dec 10 09:19:12.026 [INFO] my_cifar_run accumulated 64 samples for epoch #69 from 2 peers. ETA 3.59 sec (refresh in 1.44 sec)
# Dec 10 09:19:12.109 [INFO] Averaged parameters with 2 peers
# Dec 10 09:19:12.120 [INFO] Received parameters from background averaging round
# Dec 10 09:19:13.718 [INFO] my_cifar_run accumulated 1856 samples for epoch #69 from 2 peers. ETA 8.43 sec (refresh in 3.37 sec)
# Dec 10 09:19:17.327 [INFO] my_cifar_run accumulated 5632 samples for epoch #69 from 2 peers. ETA 4.15 sec (refresh in 1.66 sec)
# Dec 10 09:19:19.239 [INFO] my_cifar_run accumulated 7392 samples for epoch #69 from 2 peers. ETA 2.49 sec (refresh in 1.00 sec)
# Dec 10 09:19:20.464 [INFO] my_cifar_run accumulated 8928 samples for epoch #69 from 2 peers. ETA 0.55 sec (refresh in 0.50 sec)
# Dec 10 09:19:21.208 [INFO] my_cifar_run accumulated 9984 samples for epoch #69 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:19:21.214 [INFO] Transitioning to epoch 70
# Dec 10 09:19:21.276 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:19:21.901 [INFO] my_cifar_run accumulated 64 samples for epoch #70 from 2 peers. ETA 7.07 sec (refresh in 2.83 sec)
# Dec 10 09:19:24.710 [INFO] Averaged parameters with 2 peers
# Dec 10 09:19:24.714 [INFO] Received parameters from background averaging round
# Dec 10 09:19:24.951 [INFO] my_cifar_run accumulated 64 samples for epoch #70 from 2 peers. ETA 4.02 sec (refresh in 1.61 sec)
# Dec 10 09:19:26.791 [INFO] my_cifar_run accumulated 2688 samples for epoch #70 from 2 peers. ETA 5.23 sec (refresh in 2.09 sec)
# Dec 10 09:19:29.106 [INFO] my_cifar_run accumulated 6144 samples for epoch #70 from 2 peers. ETA 2.35 sec (refresh in 0.94 sec)
# Dec 10 09:19:30.260 [INFO] my_cifar_run accumulated 7520 samples for epoch #70 from 2 peers. ETA 1.76 sec (refresh in 0.70 sec)
# Dec 10 09:19:31.212 [INFO] my_cifar_run accumulated 8480 samples for epoch #70 from 2 peers. ETA 1.16 sec (refresh in 0.50 sec)
# Dec 10 09:19:31.964 [INFO] my_cifar_run accumulated 9184 samples for epoch #70 from 2 peers. ETA 0.57 sec (refresh in 0.50 sec)
# Dec 10 09:19:32.691 [INFO] my_cifar_run accumulated 9920 samples for epoch #70 from 2 peers. ETA 0.00 sec (refresh in 0.50 sec)
# Dec 10 09:19:32.694 [INFO] Transitioning to epoch 71
# Dec 10 09:19:32.800 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:19:33.529 [INFO] my_cifar_run accumulated 64 samples for epoch #71 from 2 peers. ETA 9.54 sec (refresh in 3.82 sec)
# Dec 10 09:19:36.377 [INFO] Averaged parameters with 2 peers
# Dec 10 09:19:36.381 [INFO] Received parameters from background averaging round
# Dec 10 09:19:37.546 [INFO] my_cifar_run accumulated 1408 samples for epoch #71 from 2 peers. ETA 11.44 sec (refresh in 4.58 sec)
# Dec 10 09:19:42.332 [INFO] my_cifar_run accumulated 8480 samples for epoch #71 from 2 peers. ETA 0.77 sec (refresh in 0.50 sec)
# Dec 10 09:19:43.069 [INFO] my_cifar_run accumulated 9504 samples for epoch #71 from 2 peers. ETA 0.06 sec (refresh in 0.50 sec)
# Dec 10 09:19:43.160 [INFO] Transitioning to epoch 72
# Dec 10 09:19:43.227 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:19:43.762 [INFO] my_cifar_run accumulated 64 samples for epoch #72 from 2 peers. ETA 6.80 sec (refresh in 2.72 sec)
# Dec 10 09:19:46.678 [INFO] my_cifar_run accumulated 64 samples for epoch #72 from 2 peers. ETA 3.89 sec (refresh in 1.55 sec)
# Dec 10 09:19:46.860 [INFO] Averaged parameters with 2 peers
# Dec 10 09:19:46.865 [INFO] Received parameters from background averaging round
# Dec 10 09:19:48.475 [INFO] my_cifar_run accumulated 2048 samples for epoch #72 from 2 peers. ETA 7.22 sec (refresh in 2.89 sec)
# Dec 10 09:19:51.583 [INFO] my_cifar_run accumulated 6592 samples for epoch #72 from 2 peers. ETA 2.05 sec (refresh in 0.82 sec)
# Dec 10 09:19:52.631 [INFO] my_cifar_run accumulated 8096 samples for epoch #72 from 2 peers. ETA 1.02 sec (refresh in 0.50 sec)
# Dec 10 09:19:53.439 [INFO] my_cifar_run accumulated 9184 samples for epoch #72 from 2 peers. ETA 0.20 sec (refresh in 0.50 sec)
# Dec 10 09:19:53.653 [INFO] Transitioning to epoch 73
# Dec 10 09:19:53.710 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:19:54.134 [INFO] my_cifar_run accumulated 64 samples for epoch #73 from 2 peers. ETA 6.53 sec (refresh in 2.61 sec)
# Dec 10 09:19:56.959 [INFO] my_cifar_run accumulated 64 samples for epoch #73 from 2 peers. ETA 3.71 sec (refresh in 1.48 sec)
# Dec 10 09:19:57.403 [INFO] Averaged parameters with 2 peers
# Dec 10 09:19:57.405 [INFO] Received parameters from background averaging round
# Dec 10 09:19:58.684 [INFO] my_cifar_run accumulated 960 samples for epoch #73 from 2 peers. ETA 22.02 sec (refresh in 8.81 sec)
# Dec 10 09:20:07.699 [INFO] my_cifar_run accumulated 32 samples for epoch #74 from 2 peers. ETA 6.55 sec (refresh in 2.62 sec)
# Dec 10 09:20:07.744 [INFO] Transitioning to epoch 74
# Dec 10 09:20:07.816 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:20:10.515 [INFO] my_cifar_run accumulated 64 samples for epoch #74 from 2 peers. ETA 3.80 sec (refresh in 1.52 sec)
# Dec 10 09:20:10.774 [INFO] Averaged parameters with 2 peers
# Dec 10 09:20:10.783 [INFO] Received parameters from background averaging round
# Dec 10 09:20:12.280 [INFO] my_cifar_run accumulated 1504 samples for epoch #74 from 2 peers. ETA 10.93 sec (refresh in 4.37 sec)
# Dec 10 09:20:17.070 [INFO] my_cifar_run accumulated 5888 samples for epoch #74 from 2 peers. ETA 3.70 sec (refresh in 1.48 sec)
# Dec 10 09:20:18.759 [INFO] my_cifar_run accumulated 8320 samples for epoch #74 from 2 peers. ETA 1.04 sec (refresh in 0.50 sec)
# Dec 10 09:20:19.524 [INFO] my_cifar_run accumulated 9312 samples for epoch #74 from 2 peers. ETA 0.12 sec (refresh in 0.50 sec)
# Dec 10 09:20:19.689 [INFO] Transitioning to epoch 75
# Dec 10 09:20:19.752 [INFO] Waiting for delayed updates to finish...
# Dec 10 09:20:20.222 [INFO] my_cifar_run accumulated 64 samples for epoch #75 from 2 peers. ETA 6.63 sec (refresh in 2.65 sec)
# Dec 10 09:20:23.077 [INFO] my_cifar_run accumulated 64 samples for epoch #75 from 2 peers. ETA 3.78 sec (refresh in 1.51 sec)
# Dec 10 09:20:23.340 [INFO] Averaged parameters with 2 peers
# Dec 10 09:20:23.344 [INFO] Received parameters from background averaging round
